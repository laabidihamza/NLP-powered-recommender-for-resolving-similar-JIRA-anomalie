# %%
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/Stage PFE - VERMEG/Data/cleaned_data.csv'
# file_path = 'cleaned_data.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#                                              Comment  \
# 0  I am running the command provided by the docum...
# 1  [https://jfrog.com/help/r/jfrog-release-inform...
# 2  This is the current value I would like to chan...
# 3  Ik can get the manifest from the remote repo w...
# 4  Corresponding Log record from nginx reverse pr...
#
#                                            Comment.1  \
# 0  Hi [~accountid:6213cf7cc345490071968be0]  The ...
# 1  *According to RTDEV-5069:*\n\nThe feature is s...
# 2  [https://jfrog.atlassian.net/browse/RTFACT-154...
# 3                                                NaN
# 4                                                NaN
#
#                                            Comment.2  \
# 0  Ok, thanks for your reply. \n\nI had seen this...
# 1  [~accountid:5f79a75eac3a2d006ffcc8b7] : \n\n* ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Comment.3  \
# 0                                                NaN
# 1  [~accountid:5f79a75eac3a2d006ffcc8b7] We have ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Comment.4 Comment.5 Comment.6  \
# 0                                                NaN       NaN       NaN
# 1  Since Composer *Virtual* Repository supports o...       NaN       NaN
# 2                                                NaN       NaN       NaN
# 3                                                NaN       NaN       NaN
# 4                                                NaN       NaN       NaN
#
#   Comment.7 Comment.8 Comment.9  ... Comment.52 Comment.53 Comment.54  \
# 0       NaN       NaN       NaN  ...        NaN        NaN        NaN
# 1       NaN       NaN       NaN  ...        NaN        NaN        NaN
# 2       NaN       NaN       NaN  ...        NaN        NaN        NaN
# 3       NaN       NaN       NaN  ...        NaN        NaN        NaN
# 4       NaN       NaN       NaN  ...        NaN        NaN        NaN
#
#   Comment.55 Comment.56 Comment.57 Comment.58  \
# 0        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN
#
#                                          Environment  \
# 0  version we are running is: Artifactory Online ...
# 1                                                NaN
# 2                        Developement and Production
# 3   Artifactory-pro 7.63.14 within a docker conta...
# 4                                       Linux centos
#
#                                              Summary  \
# 0  plugin config-import not found for jfrog Artif...
# 1  RTDEV-5069 / mirroring https://asset-packagist...
# 2                    Docker - Repository Default URL
# 3       getting manifest unknown error pulling image
# 4  Caught exception while saving incoming stream ...
#
#                                          Description
# 0  I am following the steps from [https://docs.jf...
# 1  We are running Artifactory 7.63.14 and have pr...
# 2  Similar to Issue: [https://jfrog.atlassian.net...
# 3  I am getting the following error when pulling ...
# 4  We have recently upgrade Artifactory to 7.63.1...
#
# [5 rows x 62 columns]

# %%
use_model = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
df['Summary'] = df['Summary'].astype(str)

# %%
embeddings = []

# Iterate through each row of the column
for i in df['Summary']:
    # Encode the sentence using the USE model
    embedding = use_model([i])
    # Append the embedding to the list
    embeddings.append(embedding)

df['embeddingsSummary'] = embeddings

# %%
df['embeddingsSummary'][1].shape
# Out:
# TensorShape([1, 512])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
df['Summary'][700]
# Out:
# 'Authentication  problem'

# %%
df['Description'][700]
# Out:
# 'Hi,\nwe had some problems with our artifactory when the user access a virtual repo which has an local repo who you need an authenticated user.\n\n\n* virtual repo\n**  local repo 1\n**  local repo 2\n**  external repo 1\n** external repo 2\n\t\n\nPermissions Management:\n - Any Remote (on any remote repo): anonymous -> deploy\n - local-repo1-permission (local repo 1): reader-user -> read, deployer-user -> delete, deploy, annotate, read\n - local-repo2-permission (local repo 2): reader-user -> read, deployer-user -> read\n\nThe problem occur when the needed jar is in "local repo 1" and your credential are from one of the both users'

# %%
def clean_comment(comment):
  try:
    start_index = comment.index('[') + 1
    end_index = comment.rfind(']') + 1  # Use rfind for last closing bracket
    # return comment[start_index:end_index].strip()  # Remove leading/trailing whitespace
    return comment[end_index:].strip()  # Remove leading/trailing whitespace

  except ValueError:  # Handle cases where there's no list
    return comment

# %%
# Iterate through comment columns (replace 'Comment_1', 'Comment_2', etc. with your actual column names)
for col in df.filter(like='Comment'):
  df[col] = df[col].astype(str)
  df[col] = df[col].apply(clean_comment)

# %%
df.head()
# Out:
#                                              Comment  \
# 0  I am running the command provided by the docum...
# 1  for Composer Remote repositories.{quote}\n\nRT...
# 2  This is the current value I would like to chan...
# 3                                                  }
# 4  "PUT ‘REPO_PATH/s.zip’ HTTP/1.1" 400 0 "-" "py...
#
#                                           Comment.1  \
# 0
# 1  it that relevant to the situation you described?
# 2
# 3                                               nan
# 4                                               nan
#
#                                            Comment.2  \
# 0  or the command “jf plugin install config-impor...
# 1       does not support v2, only v1. We will check…
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#                                            Comment.3  \
# 0                                                nan
# 1  only supports v1. Can you explain the comment ...
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#                                            Comment.4 Comment.5 Comment.6  \
# 0                                                nan       nan       nan
# 1  Since Composer *Virtual* Repository supports o...       nan       nan
# 2                                                nan       nan       nan
# 3                                                nan       nan       nan
# 4                                                nan       nan       nan
#
#   Comment.7 Comment.8 Comment.9  ... Comment.53 Comment.54 Comment.55  \
# 0       nan       nan       nan  ...        nan        nan        nan
# 1       nan       nan       nan  ...        nan        nan        nan
# 2       nan       nan       nan  ...        nan        nan        nan
# 3       nan       nan       nan  ...        nan        nan        nan
# 4       nan       nan       nan  ...        nan        nan        nan
#
#   Comment.56 Comment.57 Comment.58  \
# 0        nan        nan        nan
# 1        nan        nan        nan
# 2        nan        nan        nan
# 3        nan        nan        nan
# 4        nan        nan        nan
#
#                                          Environment  \
# 0  version we are running is: Artifactory Online ...
# 1                                                NaN
# 2                        Developement and Production
# 3   Artifactory-pro 7.63.14 within a docker conta...
# 4                                       Linux centos
#
#                                              Summary  \
# 0  plugin config-import not found for jfrog Artif...
# 1  RTDEV-5069 / mirroring https://asset-packagist...
# 2                    Docker - Repository Default URL
# 3       getting manifest unknown error pulling image
# 4  Caught exception while saving incoming stream ...
#
#                                          Description  \
# 0  I am following the steps from [https://docs.jf...
# 1  We are running Artifactory 7.63.14 and have pr...
# 2  Similar to Issue: [https://jfrog.atlassian.net...
# 3  I am getting the following error when pulling ...
# 4  We have recently upgrade Artifactory to 7.63.1...
#
#                                    embeddingsSummary
# 0  ((tf.Tensor(0.03961963, shape=(), dtype=float3...
# 1  ((tf.Tensor(0.008936056, shape=(), dtype=float...
# 2  ((tf.Tensor(0.020218397, shape=(), dtype=float...
# 3  ((tf.Tensor(0.004147171, shape=(), dtype=float...
# 4  ((tf.Tensor(-0.024265409, shape=(), dtype=floa...
#
# [5 rows x 63 columns]

# %%
sum_input_sen = df['Summary'][700]
des_input_sen = df['Description'][700]

# %%
df["embeddingsSummary"] = df["embeddingsSummary"].tolist()

# %%
# Function to calculate cosine similarity between sentences
def calculate_similarity(input_sentence, embeddings):
  input_embedding = model([input_sentence])

  similarities = []
  for embedding in embeddings:
    similarity = cosine_similarity(input_embedding, embedding)[0][0]
    similarities.append(similarity)

  return similarities

# %%
# Calculate similarity scores
sum_similarities = calculate_similarity(sum_input_sen, df["embeddingsSummary"])

# Display results
for i, row in df.iterrows():
  Summary = row["Summary"]
  similarity = sum_similarities[i]
  print(f"Summary: {Summary}, Similarity: {similarity:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Summary: HV-1755 introduces NPE in org.hibernate.validator.internal.engine.ValidatorFactoryImpl constructor, Similarity: 0.2024
# Summary: Hibernate Validation fails with JDK15, Similarity: 0.2709
# Summary: Release 6.1.6, Similarity: 0.2055
# Summary: Hibernate-validator contains high severity vulnerability, Similarity: 0.1221
# Summary: @Min and @DecimalMin fail on BigDecimal.valueOf(Double.MIN_VALUE), Similarity: 0.1989
# Summary: Validation on classes with a bidirectional relationship cause stack overflow on 6.1.x, Similarity: 0.1602
# Summary: Optional containing a list of items is not being validated, Similarity: 0.1888
# Summary: Missing char sequence implementation, Similarity: 0.1483
# Summary: hibernate-validator unnecessarily calls the thread-unsafe CachingJPATraversableResolverForSingleValidation in hibernate-core when validating, Similarity: 0.1576
# Summary: Invalid parsing of EL expression can lead to invalid EL expressions considered valid, Similarity: 0.0938
# Summary: Building multiple ValidatorFactory instances from a single Configuration violates specification for MessageInterpolator, Similarity: 0.1351
# Summary: Avoid cloning overhead from Method.getParameterTypes(), Similarity: 0.1380
# Summary: Interpolation of primitive arrays causes a ClassCastException, Similarity: 0.0374
# Summary: @Negative*/@Positive* do not support CharSequence as documented, Similarity: 0.0865
# Summary: Some RFC5322 conform email-addresses are incorrect validated by @Email, Similarity: 0.1525
# Summary: Incorrect variables in the newly added translations, Similarity: 0.0850
# Summary: AIOOBE from validate(Object) method, Similarity: 0.2129
# Summary: Cache regex Pattern for PatternValidator, Similarity: 0.1174
# Summary: Move TCK signature check to tck-runner module, Similarity: 0.1748
# Summary: Provide a DigitsValidatorForMonetaryAmount to support @Digits on MonetaryAmounts, Similarity: 0.1390
# Summary: Add @NotNullAnyField class constraint, Similarity: 0.1706
# Summary: Missing violation when a bean is validated with different groups, Similarity: 0.1947
# Summary: Remove settings-example.xml, Similarity: 0.2275
# Summary: Polish Identification numbers are not considering length of the value, Similarity: 0.1412
# Summary: ISBN-13 algorithm does not handle checksum 10, Similarity: 0.0827
# Summary: Rounding error when having a BigDecimal at runtime with @Max/@Min annotation set on a Number field, Similarity: 0.0513
# Summary: Try to make ConstraintValidator constructors accessible if not public, Similarity: 0.1113
# Summary: Custom group sequence might cause StackOverflowError on objects with cycles, Similarity: -0.0240
# Summary: IndexOutOfBoundsException in PathImpl, Similarity: 0.2495
# Summary: In GetInstancesFromServiceLoader, do not hide ServiceConfigurationError , Similarity: -0.0003
# Summary: Upgrade spring project to 4.3.15, start seeing internal.xml.ValidationXmlParser - No META-INF/validation.xml, Similarity: 0.0522
# Summary: StackOverflowError with Hibernate Validator 6.0.13.Final, Similarity: 0.1760
# Summary: Support {validatedValue} when interpolating message parameters, Similarity: 0.1191
# Summary: Audit new privileged calls in the reflection abstraction, Similarity: 0.1346
# Summary: Use simple parameters (not EL variables) for LuhnCheck and Mod*Check, Similarity: 0.1483
# Summary: No validator could be found when constraint is on interface, Similarity: 0.2542
# Summary: French translations are badly encoded, Similarity: 0.0967
# Summary: Using Hibernate Validator with Java 11 brings JavaFX on the classpath, Similarity: 0.0979
# Summary: Significant contention in Hibernate validation TypeResolver usage, Similarity: 0.1926
# Summary: TypeAnnotationAwareMetaDataProvider does not resolve generic field types with type parameters, Similarity: 0.0288
# Summary: PropertyNotFoundException for @DecimalMax when using the German translation, Similarity: 0.0620
# Summary: Exception thrown when trying to use ValidateableBeanFilter, Similarity: 0.2179
# Summary: Filter out synthetic parameters as added by Kotlin (and probably others), Similarity: -0.0151
# Summary: Unable to specify constraints at more than 1 nested parameter of a typed container, Similarity: 0.2210
# Summary: Reenable OSGi tests for JDK 10, Similarity: 0.0823
# Summary: Initializing JPATraversableResolver fails with IllegalAccessException, Similarity: 0.1911
# Summary: Optional.empty with @NotBlank on the type field fails validation, Similarity: 0.1593
# Summary: @Positive (et al) not valid for Optional<BigDecimal/BigInteger>, Similarity: 0.0839
# Summary: "Out of range" issue with an Integer validator, Similarity: 0.2419
# Summary: NPE upon upgrade from HV 5.x to 6.0.8, Similarity: 0.1920
# Summary: @SafeHtml should support adding enforced attributes, Similarity: 0.0890
# Summary: Remove the SLF4J dependency in our WildFly module - WF 13, Similarity: 0.1604
# Summary: CDI extension uses deprecated method, Similarity: 0.1089
# Summary: Add a buffer parameter to the @PastOrPresent, Similarity: 0.1695
# Summary: Align dependency versions with what's in WildFly 11, Similarity: 0.1757
# Summary: OSGi tests running on Payara fail randomly, Similarity: 0.0892
# Summary: Validator not found for @Size on non-parameterized Map/Collection properties, Similarity: 0.1349
# Summary: Refactor ValidatorImpl to allow C2 compiler to inline methods, Similarity: 0.1073
# Summary: Reduce the number of calls to ReflectionHelper#getValue(), Similarity: 0.1078
# Summary: Allow getter constraints to be specified for subclasses in XML configuration, Similarity: 0.1798
# Summary: "must not be null" violation triggered while should not, Similarity: 0.1083
# Summary: Add CodePointLength to supported AP types, Similarity: 0.0289
# Summary: ClassCastException in ValidationException.isAlreadyValidatedForCurrentGroup, Similarity: 0.1588
# Summary: Create separate validation context for different validation kinds, Similarity: 0.1395
# Summary: Use maven-flatten-plugin to produce POMs only containing runtime info, Similarity: 0.0846
# Summary: Call both initialize() methods of ConstraintValidator and HibernateConstraintValidator, Similarity: 0.1234
# Summary: E-mail validator does not allow IDN ascii domain labels, Similarity: 0.2014
# Summary: @NotNull doesn't work in 50% when annotated method is extended from multiple classes, Similarity: 0.1542
# Summary: ClassCastException when validating input of Spring MVC mapping in Weblogic 12c, Similarity: 0.2455
# Summary: Privilege escalation when running under the security manager, Similarity: 0.2062
# Summary: Add @CodePointLength constraint that validates code point length, Similarity: 0.1979
# Summary: Correct way of pulling Hibernate Validator 6.0.2.final via Gradle?, Similarity: 0.1874
# Summary: Hibernate Validator specific @NotEmpty used on return type throws an exception, Similarity: 0.1376
# Summary: Support a temporal validation tolerance when applying temporal constraints, Similarity: 0.2063
# Summary: Descriptor hasConstraints() does not take into account container element constraints, Similarity: 0.1814
# Summary: Performance penalty calling Throwable.getStackTrace(), Similarity: 0.0525
# Summary: Use Java 8 cuteness for hashCode()/equals(), Similarity: 0.0954
# Summary: @Valid ignores Iterables/Arrays returned by methods with a generic return type, Similarity: 0.1294
# Summary: Document requirement of java.xml.bind module on Java 9 when using XML descriptors, Similarity: 0.1390
# Summary: hibernate-validator-cdi has invalid OSGi manifest, Similarity: 0.1590
# Summary: Improve IPv4 validation in email addresses, Similarity: 0.1588
# Summary: Don't depend on "java.desktop" module, Similarity: 0.1108
# Summary: Properly reset the context after constraint validation, Similarity: 0.1923
# Summary: ConstraintValidatorCheck should be made a warning, Similarity: 0.0124
# Summary: Add a @UniqueElements constraints, Similarity: 0.2791
# Summary: BeanMetaDataImpl.BeanMetaDataBuilder#build() can choose ConstraintMetaData w/o constraints, Similarity: 0.1527
# Summary: Remove metadata for unconstrained methods from the aggregated metamodel, Similarity: 0.1285
# Summary: Remove UnconstrainedEntityMetaDataSingleton, Similarity: 0.1683
# Summary: Remove BeanConfiguration cache in AnnotationMetadataProvider, Similarity: 0.1312
# Summary: Support container only detectable at runtime for global cascaded validation and introduce a cache for the value extractors, Similarity: 0.1267
# Summary: Look at reducing the runtime memory usage of the ValidatorFactory, Similarity: 0.0555
# Summary: Reference documentation update, Similarity: 0.0640
# Summary: CDI Integration uses deprecated API, Similarity: 0.1508
# Summary: Cache TypeVariableBindings results and makes it a BiMap, Similarity: 0.0404
# Summary: Decide what to do about temporal constraints for duration types, Similarity: 0.0863
# Summary: Consider to bring back @UnwrapValidatedValue, Similarity: 0.0772
# Summary: Fix CascadingMetaData for arrays, Similarity: 0.1962
# Summary: StackOverflowError during compilation with annotation-processor enabled, Similarity: 0.0280
# Summary: Validator calls objects hashCode() after failed @NotNull validation, Similarity: 0.2107
# Summary: Add programmatic definitions for @Positive/@Negative and allegates, Similarity: 0.1001
# Summary: Update NotEmptyDef, NotBlankDef... to use the specification constraints, Similarity: 0.1211
# Summary: Set up performance test for validation triggered via Spring, Similarity: 0.1437
# Summary: Support for non-standard Java beans, Similarity: 0.1487
# Summary: Incorrect value handler on trace logging, Similarity: 0.1656
# Summary: Broken link in documentation: "Anatomy of Credit Card Numbers", Similarity: 0.0985
# Summary: Validator#validateValue on a class with constraints leads to a ClassCastException, Similarity: 0.1283
# Summary: Un-nest @SafeHtml.Tag.Attribute by one level, Similarity: 0.0131
# Summary: Determine what happens when we override a method and have a slightly different parameterized type, Similarity: 0.1129
# Summary: Drop WARN log message in ParameterMessageInterpolator instantiation, Similarity: 0.0869
# Summary: Support Validation Groups on @Valid annotation, Similarity: 0.2463
# Summary: Explore extension of meta-model to cover container element constraints, Similarity: 0.1898
# Summary: Split *ForNumber validators in an implementation per type, Similarity: 0.1012
# Summary: Hibernate-Validator is missing some of the OSGI export-package definitions, Similarity: 0.0521
# Summary: hibernate-validator-cdi artefact is not OSGI'ed, Similarity: 0.0265
# Summary: Rename org.hibernate.type.decriptor.ValueExtractor, Similarity: 0.2129
# Summary: Message interpolation fails with single opening or closing brace in regex character class, Similarity: 0.1388
# Summary: Add affected validator classes to exception messages if there are multiple matching ones, Similarity: 0.1606
# Summary: Expand the initial capacity of future/past validators list for added validators, Similarity: 0.1137
# Summary: Raise specific subtype of ValidationException if EL libraries aren't present, Similarity: 0.0740
# Summary: Implement constraint and validator for java.time.Duration, Similarity: 0.1866
# Summary: Unpack the schemas coming from BV, Similarity: 0.0632
# Summary: Add missing programmatic constraint definitions , Similarity: 0.1985
# Summary: Avoid usage of tables in reference docs where feasible, Similarity: 0.1364
# Summary: Rework the common release scripts to support Asciidoctor output, Similarity: 0.0342
# Summary: Implementation of @CPF is wrong, Similarity: 0.2134
# Summary: Don't use @Repeatable on some constraints, Similarity: 0.1441
# Summary: Allow to specify a field for reporting constraint violations from @ScriptAssert, Similarity: 0.1520
# Summary: @Past and @Future break with too far in past/future for Java8, Similarity: 0.0133
# Summary: Switch to LinkedHashSet to preserve order of constraints and messages, Similarity: 0.1315
# Summary: Support JDK9 ea+148, Similarity: 0.1933
# Summary: JaCoCo code coverage fails since ConstraintDescriptorImpl#buildAnnotationParameterMap() does not filter out synthetic methods, Similarity: 0.0841
# Summary: Use annotation @NotNull for set with @NotBlank on set values, Similarity: 0.1498
# Summary: getDynamicPayload(Class<C> type) throws Nullpointerexception, Similarity: 0.1075
# Summary: Update previous stable for japicmp before release, Similarity: 0.0947
# Summary: Clean-up around ConstraintLocation, Similarity: 0.0462
# Summary: ClassLoader issues in modularized environments, Similarity: 0.1585
# Summary: Update the XML schema images of the documentation for BV 2.0, Similarity: 0.0136
# Summary: Link JavaDocs of javax.money, Similarity: 0.1420
# Summary: Asciidoc Docbook processing is missing the sourcedir attribute, Similarity: 0.0625
# Summary: Add group inheritance chapter in HV documentation, Similarity: 0.0918
# Summary: EL once again a hard requirement, Similarity: 0.1129
# Summary: Ensure 5.3 runs on JDK 9, Similarity: 0.1716
# Summary: ValueContext is using OptionalValueUnwrapper for all fields, Similarity: 0.0099
# Summary: Add integration test for javax.money validation on WildFly, Similarity: 0.2244
# Summary: Support JDK 1.8.0_102 and its stricter unmarshalling, Similarity: 0.1334
# Summary: Allow reference to types in JavaDoc without FQN , Similarity: 0.0996
# Summary: OSGi tests fail using JDK 8, Similarity: 0.1378
# Summary: Issues when using XML validation configuration, Similarity: 0.2980
# Summary: Support quoted local part and extend tests around @Email constraint, Similarity: 0.0986
# Summary: ValidationMessages for Russian, Similarity: 0.0096
# Summary: Provide module ZIP file for easily upgrading Hibernate Validator in a WildFly instance, Similarity: 0.1609
# Summary: java.lang.StackOverflowError generated when using too big validation message, Similarity: 0.2318
# Summary: Unexpected behavior multi threads accessing ConstraintValidatorManager, Similarity: 0.1868
# Summary: HibernateValidation sometimes fails to load the Validation Constraints from method, Similarity: 0.2378
# Summary: Disable bundle aggregration for named modules on Java 9, Similarity: 0.1135
# Summary: Parameter validation does not stop when group in sequence has cascaded constraint violations., Similarity: 0.1481
# Summary: HV-1049 prevents annotations in the default package working, Similarity: 0.1767
# Summary: Replace fest-assert with assertj, Similarity: 0.0993
# Summary: Allow public API to access validation metadata in a developer friendly way, Similarity: 0.1774
# Summary: email domains with a 63 character length fails EmailValidator, Similarity: 0.2386
# Summary: Upgrade dependencies used by OSGi integration tests, Similarity: 0.1058
# Summary: Use type annotations for map values with @NotNull annotation on the map, Similarity: 0.1189
# Summary: Include new Matches constraint in messages, Similarity: 0.1965
# Summary: Default group sequence does not honour group hierarchy, Similarity: -0.0475
# Summary: Catch correct exception type in AbstractMessageInterpolator, Similarity: 0.1108
# Summary: OSGi tests fail using JDK 9, Similarity: 0.1446
# Summary: Correctly interpret version string returned by JDK 9, Similarity: 0.1531
# Summary: Not defined order of composed constraints processing, Similarity: 0.1575
# Summary: How to disable a particular rule on Validator#validateParameters(), Similarity: 0.1648
# Summary: Field-level constraint performance impairment, Similarity: 0.1718
# Summary: Improve OSGi integration addressing class loading issues, Similarity: 0.1738
# Summary: Provide OSGi-compatible validation provider resolver, Similarity: 0.2455
# Summary: Infinite Loop when validating custom type constraint under certain inheritance scheme, Similarity: 0.1558
# Summary: Type parameter validations are not executed against all elements in a collection if elements contain the same object instance., Similarity: 0.0496
# Summary: JavaFX Compile errors when building with OpenJDK, Similarity: 0.0769
# Summary: Exceptions during execution of LoadClass don't provide enough context, Similarity: 0.0565
# Summary: Configuration streams not reusable on IBM JVM , Similarity: 0.0490
# Summary: Hibernate Validator can't introspect AnnotatedParameterizedTypes from method parameters using IBM JDK, Similarity: 0.2192
# Summary: Validator fails with Google App Engine due to use of restricted class java.util.ResourceBundle.Control, Similarity: 0.2422
# Summary: Monitor contention at ValidatorFactoryImpl, Similarity: 0.0487
# Summary: ConstraintValidatorContext should allow to attach arbitrary context information to a ConstrainViolation, Similarity: 0.1221
# Summary: Copying PathImpl results in hashCode==0, Similarity: 0.1571
# Summary: NPE when validating an object tree whith a class whose parent has defined property constraints, Similarity: 0.1628
# Summary: javafx detection uses TCCL but JavaFXPropertyValueUnwrapper does not, Similarity: 0.0657
# Summary: Validator invokes hashCode() with null mandatory field , Similarity: 0.2182
# Summary: Generic Method is not recognized, Similarity: 0.1893
# Summary: Hibernate does not validate entity with UUID primary key on persist within a JUnit test, Similarity: 0.1994
# Summary: Unable to parse validation.xml with IBM JDK, Similarity: 0.1760
# Summary: Upgrade to WildFly 10, Similarity: 0.2173
# Summary: @Email incorrectly flags emails with 64 character length local-part as invalid, Similarity: 0.1924
# Summary: CnpjValidator validation is failing for a valid cnpj, Similarity: 0.2592
# Summary: JBoss 5.2 will not start with Hibernate Validator 5.1.3 Final, Similarity: 0.1574
# Summary: validateProperty() behaviour for prop paths with a Set/ List inconsistent with validateValue() , Similarity: 0.1250
# Summary: @NotEmpty and @NotBlank definition is not consistent with other constraints, Similarity: 0.0369
# Summary: Not able to override @NotEmpty default message using spring message source, Similarity: 0.2208
# Summary:  Failed to define class org/hibernate/validator/ValidationMessages, Similarity: 0.1784
# Summary: Annotated interface not causing validation on beans implementing it, Similarity: 0.2116
# Summary: OSGi metadata is missing optional import for com.thoughtworks.paranamer, Similarity: 0.0777
# Summary: Documentation not very clear: do I need interceptor to trigger method validation?, Similarity: 0.2352
# Summary: Add constraint annotations for Polish identification numbers, Similarity: 0.2038
# Summary: IllegalArgumentException on PathImpl#getPathWithoutLeafNode(), Similarity: 0.1235
# Summary: ConcurrentReferenceHashMap is inadvertently licensed as LGPL, Similarity: 0.0828
# Summary: ConstraintValidatorContext buildConstraintViolationWithTemplate not reading message string, Similarity: 0.1901
# Summary: Update to Classmate 1.1.0 or latest, Similarity: 0.0679
# Summary: Support @Pattern for numerical types, Similarity: 0.1183
# Summary: SNAPSHOT deploy fails with compiler error, Similarity: 0.1077
# Summary: Remove @Future and @Past validators validation partial dates, Similarity: 0.1236
# Summary: Store violated element of a java.util.Set in Path, Similarity: 0.1038
# Summary: Generic method is not validated, Similarity: 0.1812
# Summary: OptionalValueUnwrapper needs to handle null values passed to handleValidatedValue, Similarity: 0.1194
# Summary: Optional and Type Annotations, Similarity: 0.0616
# Summary: NullPointerException in ValueContext.appendNode, Similarity: 0.1893
# Summary: Docbook build needs access to JBoss Maven repository , Similarity: 0.1280
# Summary: Avoid accessing package javax.xml.stream.* when not working with XML descriptors, Similarity: 0.1665
# Summary: No tests are executed for the CDI module, Similarity: 0.0403
# Summary: ParameterNameProvider is called on methods with no parameter as well as Object methods, Similarity: 0.0953
# Summary: Create a dedicated module for the testutils code, Similarity: 0.1535
# Summary: Upgrade to the latest JBoss Logging version, Similarity: 0.1755
# Summary: Remove Chronos/JMeter performance test harness and replace with JMH based tests, Similarity: 0.0159
# Summary: Create test running Validator with security manager enabled, Similarity: 0.3097
# Summary: Create Karaf-based integration test for running HV in OSGi, Similarity: 0.1664
# Summary: CPF validation, Similarity: 0.2329
# Summary: Using Validator.validate does not work with lazy collections, Similarity: 0.1705
# Summary: Using the fluent API in a JavaEE environment, Similarity: 0.1885
# Summary: PersistenceUtilHelper can't access to inherited methods, Similarity: 0.2141
# Summary: Make expression variables accessible from ConstraintViolation, Similarity: 0.1533
# Summary: Wrong warning log in TypeAnnotationAwareMetaDataProvider.getTypeParameter, Similarity: 0.3591
# Summary: When use the @CreditCardNumber, output the WARN log , Similarity: 0.0427
# Summary: Incorrect JPA 2 detection, Similarity: 0.2562
# Summary: French translation of @DecimalMin and @DecimalMax messages is incorrect (with inclusive parameter), Similarity: 0.1090
# Summary: French translation of @Min and @Max messages is incorrect, Similarity: 0.1479
# Summary: Documentation review and improvements (chapter 1,2,11), Similarity: 0.0092
# Summary: ConstraintDescriptorImpl.equals does not match Annotation Proxies, Similarity: 0.2613
# Summary: Support configuration of unwrapping of validated value via XML, Similarity: 0.1738
# Summary: Make use of custom asciidoctor template to change numbering of examples and cross referencing in documentation, Similarity: 0.0412
# Summary: Method validation works unstable on methods with List parameter, Similarity: 0.2322
# Summary: Can't interpolate messages with variables containing format “${…}”?, Similarity: 0.1611
# Summary: @CPF and @CPNJ only works with input containing puctuation characters like 134.241.313-00, Similarity: 0.1731
# Summary: IllegalArgumentException using Java 8 and implementing ConstraintValidator, Similarity: 0.1381
# Summary: Using NaN and Infinity triggers an exception for (Decimal)Min and (Decimal)Max constraints, Similarity: 0.0492
# Summary: ConstraintLocation does not specify equals() and hashCode(), Similarity: 0.1631
# Summary: Minimum requirement for 5.5.2 is Java 7 not Java 6 as indicated, Similarity: 0.1704
# Summary: ValidatorImpl mixes contexts between validations, Similarity: 0.1158
# Summary: Upgrade TCK Runner to use latest JSR-303 TCK, Similarity: 0.0793
# Summary: Remove license headers in source files, Similarity: 0.1037
# Summary: Make HV 5.1.x compatible with Java 6, Similarity: 0.2791
# Summary: URLValidator performance, Similarity: 0.0946
# Summary: Allow to specify programmatic constraint mappings when not bootstrapping the VF manually, Similarity: 0.1778
# Summary: Use map implementation safe for concurrent access in MetaDataProviderKeyedByClassName, Similarity: 0.1682
# Summary: Disable BeanMetaDataManagerTest, Similarity: 0.2444
# Summary: Make it possible to import the project in Eclipse, Similarity: 0.0390
# Summary: Document permissions required to run Hibernate Validator with a security manager, Similarity: 0.2851
# Summary: Provide a way to run the test suite using a security manager, Similarity: 0.2450
# Summary: Improve integration with Java's security manager, Similarity: 0.2209
# Summary: Constraint Violation Exception on populated List Field @NotEmpty, Similarity: 0.1478
# Summary: Email Validator does not support trimming, Similarity: 0.1696
# Summary: Unwanted classes during build created in source tree of annotation-processor, Similarity: 0.0003
# Summary: org.hibernate.validator.constraints.CreditCardNumber does not fail on a non-numbers string, Similarity: 0.2155
# Summary: Allow for auto unwrapping of values, Similarity: 0.1918
# Summary: Support nested unwrapping, Similarity: 0.2622
# Summary: Improve error message HV000030, Similarity: 0.2650
# Summary: Cascading validation does not work on classes which implement Iterable., Similarity: 0.0985
# Summary: Luhn Credit Card Validator incorrect return statement, Similarity: 0.1760
# Summary: Provide custom constraints @Before and @After for time based types which cannot be mapped to an instant, Similarity: 0.1311
# Summary: Create a TimeProvider contract to get the current data time , Similarity: 0.0357
# Summary: Improve execution speed of BeanMetaDataManagerTest under JDK 8, Similarity: 0.0644
# Summary: Update javadoc css templates to match the JDK doclet output, Similarity: 0.0035
# Summary: CDI extension doesn't trigger validation if a method parameter is of a type parameter type, Similarity: 0.1333
# Summary: Translation error in ValidationMessages_zh_CN.properties, Similarity: 0.2123
# Summary: ValidationMessage for Korean, Similarity: 0.1380
# Summary: Validator ParanamerParameterNameProvider with inheritance, Similarity: 0.2063
# Summary: Javadoc of URL constraint is really misleading, Similarity: 0.1991
# Summary: Contention generated on runtime lookup for @GroupSequence annotation, Similarity: 0.1202
# Summary: @NotEmpty  NoSuchMethodException, Similarity: 0.0732
# Summary: ValidationExtension must not expect a ProcessBean event to be fired right after AfterBeanDiscovery.addBean() is called, Similarity: 0.0031
# Summary: @CreditCardNumber throws PropertyNotFoundException on validation error, Similarity: 0.1886
# Summary: Integrate with the new Optional type and/or JavaFX types, Similarity: 0.0325
# Summary: Use type annotations to support constraints on collection elements, Similarity: 0.0659
# Summary: Mark built-in constraints with @Repeatable, Similarity: 0.1631
# Summary: Support new date/time datatypes (JSR 310), Similarity: 0.1583
# Summary: @SafeHtml(whitelistType = WhiteListType.NONE) allow <td>, <tr>, Similarity: 0.2034
# Summary: Implement optional relaxation of parameter validation consistent with Section 4.5.5, Similarity: 0.1020
# Summary: hv test suite isn't compatible with java 8, Similarity: 0.1256
# Summary: Infinite Loop in TypeHelper.normalize(), Similarity: 0.1146
# Summary: ClassCastException when attempting to execute a validated method, Similarity: 0.2433
# Summary: java.lang.NullPointerException at org.hibernate.validator.internal.cdi.InjectingConstraintValidatorFactory.releaseInstance, Similarity: 0.1461
# Summary: Cross-parameter constraint is disallowed by Annotation Processor, Similarity: 0.1593
# Summary: Deprecated Persistence Provider is invoked, Similarity: 0.1979
# Summary: ExecutableHelper#overrides() should take visibilities into account, Similarity: -0.0045
# Summary: AIOOBE in ReflectionHelper#parametersResolveToSameTypes, Similarity: 0.0882
# Summary: Leverage validated value unwrapper for validateProperty() and validateValue(), Similarity: 0.0029
# Summary: ValidatorFactoryBean should use default BV provider, Similarity: 0.1806
# Summary: Move settings-example.xml to src/main/settings, Similarity: 0.1050
# Summary: During a release the build should run against a clean local Maven repo using a separate settings file, Similarity: 0.0497
# Summary: Remove deprecated class ValueFormatterMessageInterpolator, Similarity: 0.1063
# Summary: Provide a NonElMessageInterpolator for usecases where no EL is provided, Similarity: -0.0278
# Summary: Also package portable validations seperately, Similarity: 0.0437
# Summary: ValidationContext$BeanAndPath shouldn't access hashCode() of validated beans, Similarity: 0.2386
# Summary: Custom constraint causes "target cannot be inferred" exception when used for return value, Similarity: 0.1176
# Summary: Make hibernate-validator-cdi OSGI compliant, Similarity: 0.1480
# Summary: Make members of non-public constraint types accessible, Similarity: 0.2109
# Summary: XmlParserHelper can leak deployment classloader in wildfly integration, Similarity: 0.1258
# Summary: Annotation Processor doesn't detect errors in parameter constraints in inheritance hierarchies, Similarity: 0.1339
# Summary: Referencing constraints from within XML constrained mappings, Similarity: 0.1239
# Summary: ReflectionHelper leaks deployment classes in wildfly integration, Similarity: 0.1587
# Summary: Re-enable CustomValidatorFactoryInPersistenceUnitIT#testValidatorFactoryPassedToPersistenceUnit, Similarity: 0.2408
# Summary: @Valid not processed from XML file, Similarity: 0.1869
# Summary: Update to Classmate 1.0.0, Similarity: 0.1255
# Summary: Support curly braces within EL expressions, Similarity: 0.0280
# Summary: Use constant to define interceptor priority, Similarity: 0.0948
# Summary: @NotNull check fails in String attribute when using group validation, Similarity: 0.2283
# Summary: Provide a mechanism to automatically discover custom constraint validators, Similarity: 0.1133
# Summary: Automatically update documentation related information on hibernate.org during release, Similarity: -0.0162
# Summary: Integration with Java 8, Similarity: 0.1504
# Summary: Use WildFly for integration tests, Similarity: 0.1942
# Summary: Provide contract for customization of property names in constraint violation, Similarity: 0.1690
# Summary: Add check on default message to recognize missing {} for keys, Similarity: 0.1838
# Summary: Improve reference documentation for EL interpolation, Similarity: 0.0388
# Summary: Support possibility to include the current day/instant and set a resolution in @Future and @Past, Similarity: -0.0196
# Summary: Add an API/SPI which allows to make the process of value retrieval customizable, Similarity: 0.0559
# Summary: ArrayIndexOutOfBoundsException in ReflectionHelper#parametersResolveToSameTypes(), Similarity: 0.1701
# Summary: Rethink Validator SafeHtml design to support custom "WhiteListType", Similarity: 0.1395
# Summary: Ensure Android compatibility, Similarity: 0.1653
# Summary: German translation of @Length message is incorrect, Similarity: 0.0992
# Summary: Re-consider semantics of options of mod check constraints, Similarity: 0.0861
# Summary: Make @Mod10 check constraint more generic, Similarity: 0.1602
# Summary: Make @Mod10Check and @Mod11Check constraints usable via API, Similarity: 0.2388
# Summary: Validator that allows null but no empty strings, Similarity: 0.1857
# Summary: Create Dedicated Mod10 and Mod11 constraints, Similarity: 0.1982
# Summary: Brazilian CPF and ModCheck Validator are returning false positives, Similarity: 0.1500
# Summary: Avoid redundant specification of type for GenericConstraintDef, Similarity: 0.0720
# Summary: Use Java 8 parameter naming facility, Similarity: 0.1251
# Summary: Investigate integration with ParaNamer, Similarity: 0.1334
# Summary: Annotation processor does not flag constraints on methods that override or implement superclass or interface methods, Similarity: 0.0920
# Summary: org.hibernate.HibernateException: No Hibernate Session bound to thread, Similarity: 0.2052
# Summary: EANValidator removed from the latest versions, Similarity: -0.0886
# Summary: Escaping validator messages doesn't work, Similarity: 0.3072
# Summary: JAXB class generation fails w/ OpenJDK, Similarity: 0.0833
# Summary: Fail during building of validator factory in case EL dependencies are missing, Similarity: 0.1630
# Summary: EL dependency causes incompatibility with Tomcat 6, Similarity: 0.2237
# Summary: Change EL impl dependency scope from runtime to provided, Similarity: 0.0672
# Summary: Update dependencies for CDI, Weld etc., Similarity: 0.0682
# Summary: javax.enterprise.inject.spi.Bean implementations should also implement PassivationCapable, Similarity: 0.0789
# Summary: Investigate whether dependency on EL implementation could be made optional, Similarity: 0.1592
# Summary: Multiple constraint-mappings files for one constraint to not work, Similarity: 0.2222
# Summary: Use of static loggers prevent deployment as a shared library, Similarity: 0.1441
# Summary: Remove dependency to run in Android, Similarity: 0.1643
# Summary: Provide a way to deactivate cdi extension, Similarity: 0.1432
# Summary: Consider return type when detecting getter methods, Similarity: 0.1642
# Summary: @ValidateOnExecution not retrieved from overridden methods for sub-classes, Similarity: 0.1406
# Summary: Cascaded return value validation causes exception when used with Weld, Similarity: 0.1161
# Summary: Derive constraint target automatically for XML-configured constraints, Similarity: 0.0675
# Summary: Streamline usage of logging API, Similarity: 0.1736
# Summary: Align with BV API CR2 changes, Similarity: 0.0721
# Summary: On some JVM loading an array class via Class#loadClass(className) throws an exception, Similarity: 0.0933
# Summary: Ignore parameter constraints on generated sub-classes, Similarity: 0.1082
# Summary: Check transitive dependencies from CDI API, Similarity: 0.1196
# Summary: Messages using EL should stay unchanged also if RuntimeExceptions are raised, Similarity: 0.0068
# Summary: Spring Bean validation fails when method is generic, Similarity: 0.2305
# Summary: Extract re-usable functionality from CDI portable extension, Similarity: -0.0172
# Summary: Align XML parsing code with the latest xsd in the BV API, Similarity: 0.0270
# Summary: Arrays of primitive types need to be considered equivalent to arrays of their wrapper classes during validator resolution, Similarity: 0.0690
# Summary: Provide configuration option for setting default language used in @ScriptAssert, Similarity: 0.0946
# Summary: Retrieve constraint target from composing constraints for purely composed constraints, Similarity: 0.1631
# Summary: Upgrade JBoss Logging to 3.1.2.GA, Similarity: 0.1895
# Summary: Refactor programmatic API to instantiate the raw model classes directly, Similarity: 0.0363
# Summary: Provide cross-parameter validator for @ScriptAssert, Similarity: 0.2262
# Summary: Offer ability to order constraint defined on single property, Similarity: 0.1048
# Summary: Attach element descriptor for user-added path nodes, Similarity: 0.0498
# Summary: Mark dependency to UEL as provided, Similarity: 0.0628
# Summary: Upgrade Jsoups dependency , Similarity: 0.1583
# Summary: Upgrade JPA version used in HV, Similarity: 0.1572
# Summary: Create HV-specific MessageInterpolator.Context extension exposing the root bean type, Similarity: 0.1277
# Summary: CDI extension throws exception due to calling BeanManager#getBeans during AfterBeanDiscovery event processing, Similarity: 0.0470
# Summary: Failed tests:   testBeanMetaDataCanBeGarbageCollected(org.hibernate.validator.test.internal.metadata.BeanMetaDataManagerTest), Similarity: 0.2370
# Summary: Constraint is validated several times if part of several groups, Similarity: 0.1528
# Summary: ElementDescriptor is null for property nodes reached via traversing a Map- or array-typed parameter, Similarity: 0.1108
# Summary: JPATraversableResolver must handle method parameters when invoked during method validation, Similarity: 0.1897
# Summary: Throw meaningful exception in case object and method passed to validateParameters() don't match, Similarity: 0.1636
# Summary: Throw a ConstraintDefinitionException if both @Constraint and @CrossParameterConstraint are given, Similarity: 0.1094
# Summary: Enable tck-runner to run 1.1 TCK in container, Similarity: 0.1957
# Summary: Wrong license in tck-runner/src/test/resources/arquillian.xml, Similarity: 0.2763
# Summary: Path nodes representing executable return values must return null as name, Similarity: 0.0844
# Summary: ConstraintValidatorManager caching fails for XML-defined constraints, Similarity: 0.2206
# Summary: ValidatorContextImpl ignores custom ParameterNameProvider, Similarity: 0.1220
# Summary: MethodValidationContext.isReturnValueValidation throws NPE, Similarity: 0.1509
# Summary: ClassCastException due to unchecked cast in ValidatorImpl, Similarity: 0.1278
# Summary: Update JavaDoc stylesheet when building with Java 7, Similarity: 0.0909
# Summary: Add staging settings to project, Similarity: 0.1308
# Summary: Don't add JMeter API doc to distribution, Similarity: 0.1059
# Summary: Extend programmatic constraint API to support new constructs from BV 1.1, Similarity: 0.1088
# Summary: Switch build from Maven to Gradle, Similarity: 0.0662
# Summary: Enable checkstyle code style checks as part of the build, Similarity: 0.0037
# Summary: Evaluation of composed constraints should stops on first validation error when @ReportAsSingleViolation is used, Similarity: 0.2459
# Summary: Investigate possiblity to run tests in parallel, Similarity: 0.1150
# Summary: Integration tests hang when run using JDK 7, Similarity: 0.1905
# Summary: AnnotationMetaDataProvider should use #getDeclaredAnnotations instead of #getAnnotations when reading metadata from class and members, Similarity: 0.1736
# Summary: EmailValidator.isValid sometimes throws an exception instead of returning false, Similarity: 0.1420
# Summary: The MethodValidator does not work with no-interface-view EJBs, Similarity: 0.1657
# Summary: Wrong constraint validator type resolution in case of constraint placed on parameterized type in class hierachy, Similarity: 0.1979
# Summary: Assumes all getX/setX methods are bean properties and errors with "wrong number of arguments", Similarity: 0.1485
# Summary: Avoid GroupChainGenerator to use reflection at runtime, Similarity: 0.0926
# Summary: Improve error message for HV000085, Similarity: 0.2763
# Summary: Use WildFly for tck-runner module, Similarity: 0.2132
# Summary: Unable to validate methods in complex inheritance hierarchy, Similarity: 0.2124
# Summary: Hibernate Validator Doest run if annotated the Entity not the field on JSF VIEW, Similarity: 0.1710
# Summary: validateAllParameters not working for constraints on List, Similarity: 0.1878
# Summary: email handles complete address as idn label and fails for valid longer addresses, Similarity: 0.1586
# Summary: Validator.validateValue() throws UnexpectedTypeException even when the passed value has a validator., Similarity: 0.1684
# Summary: Wrong use of maven version schema, Similarity: 0.1305
# Summary: EmailValidator fails where email address is large, Similarity: 0.1750
# Summary: Email Validator producing error for large email addresses, Similarity: 0.1621
# Summary: XML based configuration fails when context class loader is not set, Similarity: 0.1185
# Summary: Docs are wrong about location of /validation.xml or the code is, Similarity: 0.1036
# Summary: NPE w/ overloaded methods on class validated with MethodValidationInterceptor, Similarity: 0.2434
# Summary: Validation assumes that the context class loader will find the defaults file, Similarity: 0.0631
# Summary: Update tck-runner module, Similarity: 0.2217
# Summary: Improve error message for unsupported validateValue() invocations, Similarity: 0.1682
# Summary: Determine how to handle different versions of validation-configuration and validation-mapping xsd, Similarity: 0.0936
# Summary: Advanced support for cascaded validation of collections, Similarity: 0.0895
# Summary: EmailValidator throws an IllegalArgumentException for long email addresses, Similarity: 0.1736
# Summary: Keep a constant metadata placeholder for unconstrained entities, Similarity: 0.1038
# Summary: Offer a property to exclude some entities from validation, Similarity: 0.1166
# Summary: stack overflow when having @Valid on cycle, Similarity: 0.0714
# Summary: Hibernate validator initializes lazy proxies, Similarity: 0.2447
# Summary: Order of validation messages is lost, Similarity: 0.1449
# Summary: Upgrade JBoss Logging dependency, Similarity: 0.2018
# Summary: Introduce a class loading service, Similarity: 0.1658
# Summary: Create link to JBoss logging in the online documentation, Similarity: 0.2232
# Summary: Remove remaining references to slf4j, Similarity: 0.0830
# Summary: Include javadoc jar in Maven repo, Similarity: 0.0518
# Summary: NPE in annotation processor ConstraintHelper.getName(), Similarity: 0.2044
# Summary: Annotations processing fails with 4.3.0 Beta1, Similarity: 0.1645
# Summary: Need graceful handling of return value constraint applied to method with void return type, Similarity: 0.1435
# Summary: Align method level validation w/ Bean Validation 1.1, Similarity: 0.2162
# Summary: Switch to Java 6, Similarity: 0.2275
# Summary: Perform a profiling of the annotation processor code and make use of caching where appropriate, Similarity: 0.1098
# Summary: @Email reported as "disallowed" for String field, Similarity: 0.1157
# Summary: Allow caching of ConstraintValidator instances also for custom ConstraintValidatorFactories, Similarity: 0.1156
# Summary: Enable Configuration#buildValidatorFactory() to be callable several times, Similarity: 0.2179
# Summary: Incorrect use of TCL to check visibility to JPA classes, Similarity: 0.1306
# Summary: Determine and mark the API to be deprecated for HV5, Similarity: 0.0609
# Summary: Investigate how reference from API packages to Log class could be avoided, Similarity: 0.1297
# Summary: Refactor package organisation to clearly separate spi, public and private APIs - part 2 (public packages), Similarity: 0.0423
# Summary: Make AggregateResourceBundleLocator an interface to be included into the public api of HV, Similarity: 0.0697
# Summary:  Regular Expression for @Email, Similarity: 0.1291
# Summary: Extract dedicated constraint module, Similarity: 0.2480
# Summary: Need additional AccessController.doPrivileged() for invoking equals() on an instance of Annotation., Similarity: 0.1509
# Summary: @Size doesn't work on List with bounded wildcard, Similarity: 0.0325
# Summary: fail-fast doesn't work on composite constraints, Similarity: 0.1656
# Summary: add method ValidatorImpl.validateElement(Annotation[], Class<?>, Type, Object value, Class<?>... groups), Similarity: 0.0723
# Summary: Make Hibernate Validator build not fail, Similarity: 0.2276
# Summary: LazyValidatorFactory does not allow alternative bean validation providers, Similarity: 0.1700
# Summary: Update TCK runner to run against AS 7.1, Similarity: 0.0813
# Summary: spelling mistake in org.hibernate.valisdator.validationMessages_fr.properties, Similarity: 0.1048
# Summary: HibernateTraversableResolver does not correctly determine if an lazy property is initialized., Similarity: 0.1282
# Summary: Remove repository settings from the master pom, Similarity: 0.1621
# Summary: Perform a profiling of the HV code in order to identify performance bottlenecks, Similarity: 0.0662
# Summary: Validator sees all nulls on proxy object when proxied entity class has constraint annotations applied to fields instead of methods, Similarity: 0.1757
# Summary: @Digits.fraction should allow negative values, Similarity: 0.0875
# Summary: Explain propagation of redefined default groups across associated instances annotated with @Valid, Similarity: 0.1049
# Summary: Compilation fails with JDK 7 due to incompatabilites of JAXB versions, Similarity: 0.0617
# Summary: ValidationMessages in Czech language, Similarity: 0.0423
# Summary: Stackoverflow on @Required, Similarity: 0.1530
# Summary: tests fail on openjdk, Similarity: 0.2499
# Summary: java.util.NoSuchElementException in type level validation using EclipseLink, Similarity: 0.1546
# Summary: Hibernate validator must be a fragment of javax.validation and should easily plug with extenders, Similarity: 0.1446
# Summary: TypeDescriptor#getConstraintsForMethod() should return null for unconstrained methods, Similarity: 0.1676
# Summary: Remove package cycle between "descriptor" and "aggregated" packages, Similarity: -0.0017
# Summary: Hibernate Validator doesn't work well with hibernate persistence when generating DDL, Similarity: 0.2152
# Summary: URL validator rejects protocols the JVM does not know about, Similarity: 0.1838
# Summary: Composed constraints lose the payload information of the constraints they are composed of, Similarity: 0.1224
# Summary: Minor documentation error, Similarity: 0.1802
# Summary: Property path is wrong for cascaded validation of class-level constraints, Similarity: 0.1837
# Summary: DecimalMaxValidatorForNumber for a double values is not correct, Similarity: 0.0293
# Summary: Specify the name of the resource file via a property, Similarity: 0.0032
# Summary: Message interpolation should check whether an interpolated annotation paramter is an array, Similarity: 0.1210
# Summary: Extend programmatic API to allow alteration of ConstraintValidator list for a given constraint, Similarity: 0.0778
# Summary: Add @URI validator to support relative URLs, Similarity: 0.1927
# Summary: When adding annotations processor compiler get's broken, Similarity: 0.1015
# Summary: Include Hibernate Validator test classes in a different classifier, Similarity: 0.1009
# Summary: Many locks on AnnotatedElements, Similarity: 0.1425
# Summary: Add support for Brazilian Portuguese for ValidationMessages, Similarity: 0.0067
# Summary: Validation of CGLIB enhanced Objects always return null, Similarity: 0.2155
# Summary: Add support for MOD11 Algorithm, Similarity: 0.1492
# Summary: Create @SafeHtml annotation, Similarity: 0.2665
# Summary: Settle on an approach for instantiating constraint definitions, Similarity: 0.1343
# Summary: Remove getMethod() from MethodConstraintViolation, Similarity: 0.1476
# Summary: Refactor package organisation to clearly separate spi, public and private APIs - part 1 (internal packages), Similarity: 0.0422
# Summary: ValidationMessages translation to Spanish, Similarity: 0.1113
# Summary: Weblogic ConstraintDeclarationException , Similarity: 0.2124
# Summary: Constraints configured via XML and programmatic API aren't merged, Similarity: 0.1097
# Summary: Implement an eviction strategy for BeanMetaDataCache, Similarity: 0.0589
# Summary: Investigate whether a switch for turning off the instantiation of the method validation meta model makes sense, Similarity: 0.1242
# Summary: Min Max and other annotations are causing exceptions in Parametrized class hierarchies, Similarity: 0.0378
# Summary: Add option to Canonicalize String Input, Similarity: 0.1993
# Summary: E-Mail Validator does not validate IDN E-Mail-Addresses, Similarity: 0.1795
# Summary: Group has to be an interface - Documentation or code bug, Similarity: 0.1581
# Summary: ClassCast exception when creating Combined constraint, Similarity: 0.1804
# Summary: Determine whether a property is indexed based on the runtime not static type, Similarity: 0.0311
# Summary: Avoid repeated validation of constraints in certain type hierarchies, Similarity: 0.1392
# Summary: Remove obsolete type parameter from MetaConstraint#validateConstraint(), Similarity: 0.1170
# Summary: Remove obsolete type parameter from ParameterMetaConstraint, Similarity: 0.0949
# Summary: Revisit the class and implementation of Group/GroupChain, Similarity: 0.0802
# Summary: Create a SerializableValidatorFactory wrapper that has enough information to either access or create a matching implementation when deserializing, Similarity: 0.2315
# Summary: Run TCK against AS 7, Similarity: 0.1586
# Summary: Wrong behaviour determining default group constraints in conjunction with @GroupSequence, Similarity: 0.2041
# Summary: Simplify annotation processor setup in IDEs in regards to required dependencies, Similarity: 0.1909
# Summary: The MethodValidator could not handle Proxied objects like in EJB environment, Similarity: 0.1169
# Summary: Incorrect Paths when using fluent API to add constraints to a context, Similarity: 0.1922
# Summary: Only the root method of an overridden method in an inheritance hierarchy may be annotated with parameter constraints, Similarity: 0.1743
# Summary: Create documentation for boolean composition of composing constraints, Similarity: 0.1326
# Summary: The annotation processor should allow constraint annotations at non-getter methods, Similarity: 0.1686
# Summary: Ensure meta models are completely immutable , Similarity: 0.0455
# Summary: Scope of ConstraintDescriptors sometimes wrong in type hierarchies, Similarity: 0.0479
# Summary: Make clear in the documentation which types are supported for built-in constraints, Similarity: 0.0380
# Summary: Refactor BeanMetaDataImpl, Similarity: 0.1612
# Summary: Revisit the use of generics in ValidatorImpl, Similarity: 0.0962
# Summary: Call to TraversableResolver.isReachable() threw an exception, Similarity: 0.1785
# Summary: The annotation processor should check @GroupSequenceProvider, Similarity: 0.1294
# Summary: org.hibernate.validator.constraints.impl.PatternValidator rejecting empty strings, Similarity: 0.1512
# Summary: ValidatorImpl#shouldFailFast() and ValidationContext#shouldFailFast() seem redundant, Similarity: 0.0377
# Summary: Cascaded validation on superclass fields does not work if only @Valid is used, Similarity: 0.1954
# ...
# Summary: Hibernate 6, wrong order by and group by generated, Similarity: 0.1438
# Summary: Converted boolean mappings not always working in predicates, Similarity: 0.0594
# Summary: AssertionError when using using native query on table with InheritanceStrategy.JOINED, Similarity: 0.1492
# Summary: Session.find should not apply filters, Similarity: 0.0745
# Summary: Catalog/schema creation/dropping sometimes ignores default catalog/schema, Similarity: 0.0490
# Summary: AssertionError in StandardEntityGraphTraversalStateImpl.traverse when using entity graph, Similarity: 0.1698
# Summary: NullPointerException when merging detached collections due to LOG.debugf, Similarity: 0.1235
# Summary: Incorrect SQL generated when using SELECT DISTINCT and @OrderBy, Similarity: 0.0986
# Summary: NPE SqmTreePrinter.visitLikePredicate getEscapeCharacter is null, Similarity: 0.2389
# Summary: Same named parameter appearing in SELECT and WHERE clauses throws JDBC parameter value not bound error, Similarity: 0.1601
# Summary: LAZY @ManyToOne may break EAGER @ManyToOne when used on the same entity in a different parent with Bytecode Enhancement, Similarity: 0.1336
# Summary: Date calculation errors in Oracle and TiDB, Similarity: 0.0855
# Summary: Named type [class xxx] did not implement BasicType nor UserType, Similarity: 0.0055
# Summary: @Embedded property not working with hibernate-enhance-maven-plugin, Similarity: 0.2148
# Summary: Named native queries do not work with jakarta.persistence.Tuple result class, Similarity: 0.1166
# Summary: Wrong translation of a DELETE JPQL Statement, Similarity: 0.0906
# Summary: NullPointerException when flushing a (simple) entity update for models with bytecode enhancement and multiple one-to-one associations (some lazy), Similarity: 0.1787
# Summary: Circular entities throwing UnknownTableReferenceException in 6.x, Similarity: 0.0931
# Summary: Hibernate no longer detects HashMap property with AttributeConverter as dirty , Similarity: 0.2187
# Summary: Passing an ExtendedBeanManager which is notified too late leads to initialization error, Similarity: 0.1247
# Summary: UnknownTableReferenceException: Unable to determine TableReference (`PM_SERVICE_GROUP`) for `com.frontierssys.infrastructure.core.framework.persistence.model.Service.serviceMapping.{fk-target}, Similarity: 0.0621
# Summary: Epoch extraction fails with "no viable alternative at input" since Hibernate 6, Similarity: 0.1268
# Summary: Converted collection-as-basic values are considered immutable, Similarity: 0.0451
# Summary: UnknownTableReferenceException with JPQL query of Entity with unidirectional OneToOne mapping , Similarity: 0.2078
# Summary: NPE Caused by "Cannot invoke "org.hibernate.engine.spi.EntityKey.getIdentifier()" because "this.entityKey" is null" @ AbstractEntityInitializer:445, Similarity: 0.2111
# Summary: Exception when find by association id that is a generic @EmbeddedId with @MappedSuperclass, Similarity: 0.2112
# Summary: Skip CDI for Hibernate extensions by default, Similarity: 0.0915
# Summary: jakarta.persistence.query.timeout not working on Hibernate 6.1.6 for Criteria Queries, Similarity: 0.2243
# Summary: join fetch in @Query has no effect for for nested entities with @DiscriminatorValue (SINGLE_TABLE inheritance), Similarity: 0.1184
# Summary: Setting a property to its current value with bytecode enhancement enabled results in unnecessary SQL Update in some (many) cases, Similarity: 0.0579
# Summary: ambiguity in grammar of HQL datetime literals, Similarity: 0.1519
# Summary: Hibernate 6.x breaks collection batch fetching, Similarity: 0.0996
# Summary: merge of a persisted entity uses an insert statement instead of an update statement resulting in duplicate entities, Similarity: 0.1463
# Summary: Duration literals and 'by' are almost completely broken, Similarity: 0.0374
# Summary: CASE Statement in jpql throws assertion error when running H2 in Oracle mode with OracleDialect, Similarity: 0.1267
# Summary: Many-to-Many inverse mapping referencing the same class uses pk instead of fk field for removal, Similarity: 0.1531
# Summary: @ManyToMany with @JoinTable(inverseColumn = ...) and SortedSet may results in data loss, Similarity: 0.1760
# Summary: Using BatchEntitySelectFetchInitializer with caching leads to caching wrong values, Similarity: 0.2072
# Summary: ArrayIndexOutOfBoundsException: Index 1 out of bounds for length 1 for NamedNativeQuery with generics, Similarity: 0.1117
# Summary: @Where not consistently applied across association boundaries, Similarity: 0.0415
# Summary: HQL Enum literals don't work for inner class enums, Similarity: 0.1580
# Summary: DefaultEvictEventListener calls handleEviction with swapped parameters, Similarity: 0.0684
# Summary: jakarta @OrderBy annotation generates a non-transformed column name in the SQL query for a composite key's field, Similarity: 0.1446
# Summary: PropertyAccessException when deleting entities with Embeddables with child collections, Similarity: 0.0679
# Summary:  @BatchSize with @ManyToMany does not work as expected when migrating 5 -> 6, Similarity: 0.1992
# Summary: Downcasting with CriteriaBuilder.treat causes ClassCastException, Similarity: 0.1106
# Summary: Unable to determine TableReference when associate ManyToOne fetch lazy and NotFound IGNORE: issue using Projection, Similarity: 0.2133
# Summary: Pagination error with Postgres   : SQL Error: 0, SQLState: 42601 ERROR: syntax error, Similarity: 0.2292
# Summary: PostgreSQLDialect db version detection failure blocks deployment, Similarity: 0.2024
# Summary: entitygraph load error when Inheritance JOINED is used in 6.1.6, Similarity: 0.1623
# Summary: Issue when combining Postgres driver, @MappedSuperclass, generics and enums, Similarity: 0.1892
# Summary: Inheritance: org.hibernate.PropertyAccessException Exception, Similarity: 0.1124
# Summary: Sporadic ClassCastException when querying for Set<Enum>., Similarity: 0.1016
# Summary: @OneToOne(mappedBy = ..., fetch = LAZY) in embedded referencing an association within another embedded , Similarity: 0.1445
# Summary: Incorrect results for pageable EntityGraph with Hibernate 6.1.6, Similarity: 0.1219
# Summary: Hibernate 6 Error : Already registered a copy: SqmBasicValuedSimplePath(fullyqualifiedclass.name), Similarity: 0.2707
# Summary: AssertionError with bidirectional OneToOne relation using AttributeConverter for the FK, Similarity: 0.2078
# Summary: jpa-modelgen fails silently upon faulty annotation, Similarity: 0.2267
# Summary: Joins on non-managed-type polymorphisms don't work, Similarity: 0.1086
# Summary: Upgrade from 5.6.2 to 6.1.6 results in fail of HQL parser (JPQL) - error when property is called "reserved", Similarity: 0.2015
# Summary: Hibernate Inheritance, Similarity: 0.2373
# Summary: @Basic(optional=false) has no effect, Similarity: 0.0516
# Summary: Mapping jsonb of different types in a class inheritance hierarchy does not work., Similarity: 0.0977
# Summary: MappingException is thrown for @JoinColumn with referencedColumnName on a @SecondaryTable - Composite Key, Similarity: 0.1670
# Summary: Upgrade to Hibernate ORM 6.1.7 with Spring 6.0.3 i have a strange error., Similarity: 0.2630
# Summary: Unrelated Entity Join throws IllegalStateException, Similarity: 0.1586
# Summary:  Regressions when using JoinColumnOrFormula on char[] and String , Similarity: 0.1548
# Summary: Deprecated method QueryProducer.createNativeQuery alternative does not work for Example 556 and 557, Similarity: 0.1006
# Summary: Hibernate testing adds log4j2, therefore the test case template should use it as well, Similarity: 0.1241
# Summary: Log "HHH000114: Handling transient entity in delete processing" shouldn't be logged on INFO level or not at all, Similarity: 0.1385
# Summary: Hibernate 6 create EMF exception, Similarity: 0.1760
# Summary: Hibernate 6 H2 dialect override Nulls precedence ignored, Similarity: 0.1220
# Summary: IllegalArgumentException :Cannot create binding for parameter referencen with criteria builder, Similarity: 0.1890
# Summary:  springboot 3.0.0 + hibernate 6.1.5.Final + IBM DB2 error after migrating from springboot 2.7.0 + hibernate 5.6.9.Final, Similarity: 0.1857
# Summary: review exception reporting in Column.getSqlType()/getSqlTypeName(), Similarity: 0.0290
# Summary: Unable to determine TableReference when using QueryBuilder treat, Similarity: 0.2302
# Summary: 1:n relation, EntityGraph and maxResults cause wrong amount of entries to be fetched, Similarity: 0.0744
# Summary: Fetch type eager issue on entity with @DiscriminatorValue, Similarity: 0.2609
# Summary: OneToMany foreign key relation throws when id is inside nested embeddables, Similarity: 0.1950
# Summary: OrphanRemoval does not work with embeddables when deleting entity, Similarity: 0.0689
# Summary: Hibernate6/Postgres14 does not map correctly java.time.Instant, Similarity: 0.1747
# Summary: NoSuchElementException when building LocalTemporaryTableMutationStrategy, Similarity: 0.1872
# Summary: Issue with hbm.xml file column mapping, Similarity: 0.2619
# Summary: Improve CollectionInitializer and EntityDelayedFetchInitializer resolveInstance methods performance when the parent entity is initialized, Similarity: 0.0851
# Summary: NullPointerException when parsing HQL query with like statement and interface is used, Similarity: 0.2250
# Summary: DDL check constraint creation broken, Similarity: 0.2068
# Summary: CriteriaBuilder treat method on Path causes ClassCastException, Similarity: 0.1182
# Summary: Sybase - store procedure unsupported named parameter, Similarity: 0.0994
# Summary: Malformed query generated when using @DiscriminatorValue, Similarity: 0.1542
# Summary: setting TIMEZONE_DEFAULT_STORAGE to COLUMN does not work, Similarity: 0.2187
# Summary: Unexpected org.hibernate.UnknownEntityTypeException: Unable to locate persister, Similarity: 0.1343
# Summary: inconsistent DDL generated Instant and ZonedDateTime, OffsetDateTime on Oracle, Similarity: 0.1214
# Summary: extract(offset hour|minute from datetime) are broken, Similarity: 0.2077
# Summary: NullPointerException in CollectionLoaderSubSelectFetch when using simple join fetch query, Similarity: 0.2511
# Summary: SubQuery with "in" results in java.lang.ClassCastException: class org.hibernate.metamodel.mapping.internal.BasicEntityIdentifierMappingImpl cannot be cast to class org.hibernate.metamodel.mapping.EntityValuedModelPart, Similarity: 0.0890
# Summary: NullPointerException when constructing mapping model for nested embeddables with not optional ManyToOne, Similarity: 0.2143
# Summary: Updating entity having @OneToOne with inverse side within embeddable leads to `ConstraintViolationException`, Similarity: 0.1611
# Summary: Primitive array as Natural ID causes ClassCastException, Similarity: 0.0558
# Summary: MSSQL: java.time.Instant doesn't work anymore after upgrading to Hibernate 6, Similarity: 0.2185
# Summary: org.hibernate.query.SemanticException: Could not interpret path expression, Similarity: 0.1381
# Summary: validation @NotNull does not mark Column as null, Similarity: 0.1853
# Summary: incorrect deprecation warning being logged: HHH90000021: Encountered deprecated setting [javax.persistence.sharedCache.mode], use [jakarta.persistence.sharedCache.mode] instead , Similarity: 0.1782
# Summary: missing unique constraints from optional @OneToOne, Similarity: 0.2823
# Summary: Hibernate.isInitialized() broken for EnhancementAsProxyLazinessInterceptor, Similarity: 0.1621
# Summary: IllegalArgumentException while executing Like query with Escapes, Similarity: 0.1883
# Summary: HQL where clause parsing fails with StackOverflow exception, Similarity: 0.2104
# Summary: Querying with empty parameter list fails, Similarity: 0.1902
# Summary: @Convert on Map should not require "attributeName=value", Similarity: 0.1250
# Summary: Regression: 'replace" function on property of enum type results in type mismatch, Similarity: 0.0469
# Summary: Disjunction with treat results in too restrictive query, Similarity: 0.1003
# Summary: broken links in 6 docs, Similarity: 0.2105
# Summary: UnknownTableReferenceException on @ElementCollection of @Embeddable containing a @MayToOne with a @ManyToMany, Similarity: 0.1625
# Summary: Hibernate Gradle plugin broken with Kotlin projects, Similarity: 0.0873
# Summary: ArgumentTypesValidator doesn't support enums in string functions, Similarity: 0.1781
# Summary: ReflectHelper and RegistryHelper do not handle generic types correctly , Similarity: -0.0041
# Summary: HQL local datetime literals on Postgres, Cockroach H2, Similarity: 0.1187
# Summary: Regression: Unable to determine TableReference when restricting on joined property, Similarity: 0.1525
# Summary: Enhancement failed for Kotlin projects, Similarity: -0.0144
# Summary: SqlFunction does not render the fragment after the last parameter, Similarity: 0.0876
# Summary: IllegalArgumentException with Type parameters and multiple bounds, Similarity: 0.0461
# Summary: Envers incorrect key parameter order in insert statement when InheritanceType.JOINED and @Embeddable ID, Similarity: 0.1947
# Summary: static final instances of LockOptions are mutable, Similarity: 0.0510
# Summary: Respect the offset of OffsetTime when persisting/loading data, Similarity: -0.0348
# Summary: LEFT JOIN in HQL creates CROSS-JOINS in SQL disabling "WHERE 1=1 OR "-wavebys, Similarity: 0.1349
# Summary: Oracle 21 and 11 spatial test failure, Similarity: 0.0873
# Summary: Mariadb is missing identifier quote on SEQUENCE QUERY, Similarity: 0.2134
# Summary: ClassCastException in Select, Similarity: 0.1989
# Summary: Embeddable with more fields than the parent fails with Index out of Bounds, Similarity: 0.1190
# Summary: Named Native Query cannot be registered/used with named parameters, Similarity: 0.1517
# Summary: Fetching association and using implicit path in condition fails, Similarity: 0.1508
# Summary: UnknownTableReferenceExceptions since 6.1.1, Similarity: 0.1386
# Summary: ClassCastException when batch-fetching association in embeddable, Similarity: 0.1484
# Summary: Lazy basic property does not get updated on change, Similarity: 0.0925
# Summary: Tolerate @XxxxToOne @JoinTable with no explicit join table name, Similarity: 0.1738
# Summary: OneToOne relationship is null when hibernate.max_fetch_depth = 1, Similarity: 0.1949
# Summary: useless error message of multi-@JoinColumn mapping does not specify referencedColumnName, Similarity: 0.1336
# Summary: @AttributeOverride has no effect when an @EmbeddedId inherits its members (UPDATE: not true), Similarity: 0.0753
# Summary: JPA Hibernate float value not taking from Column precision for DDL Generation, Similarity: 0.1030
# Summary: Query bug in @NamedEntityGraph when doing Eager loading of @OneToOne mappings in Single Table inheritance, Similarity: 0.2203
# Summary: Procedure should accept TypedParameterValue as parameter, Similarity: 0.0989
# Summary: Bad SQL generation when using entity graph with ON clause on query, Similarity: 0.1926
# Summary: get schema incorrectly in Hibernate 6.1.4, Similarity: 0.2441
# Summary: Error In Native Query where column is mapped twice, Similarity: 0.1714
# Summary: @OneToOne(mappedBy = ..., fetch = LAZY) in embedded leads to IllegalArgumentException: Can not set [...] to LazyPropertyInitializer$1, Similarity: 0.1687
# Summary: Parameter binding of converted TemporalJavaType fails, Similarity: 0.1530
# Summary: Identically-named association in entity root and elementcollection of embeddables leads to assertion error, Similarity: 0.1351
# Summary: Querying the object containing json before saving other objects will trigger the object to also be saved, Similarity: 0.1353
# Summary: ByteBuddy enhancement generates faulty code with many-to-many associations, Similarity: 0.1836
# Summary: Gradle plugin should use full compilation classpath for enhancement, Similarity: 0.0273
# Summary: Illegal Update-Statement generated, Similarity: 0.1173
# Summary: Trying to accomplish Insert bulk query with hibernate, Similarity: 0.2066
# Summary: Emulate lt/gt/le/ge tuple-comparisons when unsupported, Similarity: 0.0965
# Summary: SpannerDialect, schema creation generates SQL containing 'null' instead of the column type, Similarity: 0.1486

# %%
len(sum_similarities)
# Out:
# 9419

# %%
# Store summaries with similarity > 0.7 and their scores in a list
similar_summaries_and_scores = []
for summary, similarity in zip(df["Summary"], sum_similarities):
  if similarity > 0.5:
    similar_summaries_and_scores.append((summary, similarity))

# Sort similar summaries by similarity score (highest first)
sorted_similar_summaries_and_scores = sorted(similar_summaries_and_scores, key=lambda x: x[1], reverse=True)

# Print top 5 similar sentences and their scores
for i, (summary, similarity) in enumerate(sorted_similar_summaries_and_scores):
  if len(sum_similarities) == 0:
    print('No similar tickets found.')
  if i == 5:
    break  # Print only the top 5
  print(f"Similar summary: {summary} \n , Similarity: {similarity:.4f} \n")
# Out:
# Similar summary: Authentication  problem
#  , Similarity: 1.0000
#
# Similar summary: Authentication
#  , Similarity: 0.7818
#
# Similar summary: Random authentification Issues
#  , Similarity: 0.6995
#
# Similar summary: Cannot log-in
#  , Similarity: 0.6109
#
# Similar summary: Invalid authentication removes groups from Crowd-users
#  , Similarity: 0.5257

# %%
len(similar_summaries_and_scores)
# Out:
# 7

# %%
def merge_comments(df):

  comment_cols = ['Comment', 'Comment.1', 'Comment.2', 'Comment.3', 'Comment.4', 'Comment.5', 'Comment.6', 'Comment.7', 'Comment.8', 'Comment.9', 'Comment.10', 'Comment.11', 'Comment.12', 'Comment.13', 'Comment.14', 'Comment.15', 'Comment.16', 'Comment.17', 'Comment.18', 'Comment.19', 'Comment.20', 'Comment.21', 'Comment.22', 'Comment.23', 'Comment.24', 'Comment.25', 'Comment.26', 'Comment.27', 'Comment.28', 'Comment.29', 'Comment.30', 'Comment.31', 'Comment.32', 'Comment.33', 'Comment.34', 'Comment.35', 'Comment.36', 'Comment.37', 'Comment.38', 'Comment.39', 'Comment.40', 'Comment.41', 'Comment.42', 'Comment.43', 'Comment.44', 'Comment.45', 'Comment.46', 'Comment.47', 'Comment.48', 'Comment.49', 'Comment.50', 'Comment.51', 'Comment.52', 'Comment.53', 'Comment.54', 'Comment.55', 'Comment.56', 'Comment.57', 'Comment.58']

  # filter non-NaN comments
  def filter_comments(row):
    return [comment for comment in row[comment_cols] if pd.notna(comment)]

  # Create a new column 'combined_comments' to store merged comments
  df['Comments'] = df.apply(filter_comments, axis=1)

  # Iterate through rows and build comment lists
  for index, row in df.iterrows():
    comments = [comment for comment in row[comment_cols] if pd.notnull(comment)]
    df.at[index, 'Comments'] = comments

  return df

df = merge_comments(df.copy())

df.head()
# Out:
#                                              Comment  \
# 0  I am running the command provided by the docum...
# 1  for Composer Remote repositories.{quote}\n\nRT...
# 2  This is the current value I would like to chan...
# 3                                                  }
# 4  "PUT ‘REPO_PATH/s.zip’ HTTP/1.1" 400 0 "-" "py...
#
#                                           Comment.1  \
# 0
# 1  it that relevant to the situation you described?
# 2
# 3                                               nan
# 4                                               nan
#
#                                            Comment.2  \
# 0  or the command “jf plugin install config-impor...
# 1       does not support v2, only v1. We will check…
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#                                            Comment.3  \
# 0                                                nan
# 1  only supports v1. Can you explain the comment ...
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#                                            Comment.4 Comment.5 Comment.6  \
# 0                                                nan       nan       nan
# 1  Since Composer *Virtual* Repository supports o...       nan       nan
# 2                                                nan       nan       nan
# 3                                                nan       nan       nan
# 4                                                nan       nan       nan
#
#   Comment.7 Comment.8 Comment.9  ... Comment.54 Comment.55 Comment.56  \
# 0       nan       nan       nan  ...        nan        nan        nan
# 1       nan       nan       nan  ...        nan        nan        nan
# 2       nan       nan       nan  ...        nan        nan        nan
# 3       nan       nan       nan  ...        nan        nan        nan
# 4       nan       nan       nan  ...        nan        nan        nan
#
#   Comment.57 Comment.58                                        Environment  \
# 0        nan        nan  version we are running is: Artifactory Online ...
# 1        nan        nan                                                NaN
# 2        nan        nan                        Developement and Production
# 3        nan        nan   Artifactory-pro 7.63.14 within a docker conta...
# 4        nan        nan                                       Linux centos
#
#                                              Summary  \
# 0  plugin config-import not found for jfrog Artif...
# 1  RTDEV-5069 / mirroring https://asset-packagist...
# 2                    Docker - Repository Default URL
# 3       getting manifest unknown error pulling image
# 4  Caught exception while saving incoming stream ...
#
#                                          Description  \
# 0  I am following the steps from [https://docs.jf...
# 1  We are running Artifactory 7.63.14 and have pr...
# 2  Similar to Issue: [https://jfrog.atlassian.net...
# 3  I am getting the following error when pulling ...
# 4  We have recently upgrade Artifactory to 7.63.1...
#
#                                    embeddingsSummary  \
# 0  ((tf.Tensor(0.03961963, shape=(), dtype=float3...
# 1  ((tf.Tensor(0.008936056, shape=(), dtype=float...
# 2  ((tf.Tensor(0.020218397, shape=(), dtype=float...
# 3  ((tf.Tensor(0.004147171, shape=(), dtype=float...
# 4  ((tf.Tensor(-0.024265409, shape=(), dtype=floa...
#
#                                             Comments
# 0  [I am running the command provided by the docu...
# 1  [for Composer Remote repositories.{quote}\n\nR...
# 2  [This is the current value I would like to cha...
# 3  [}, nan, nan, nan, nan, nan, nan, nan, nan, na...
# 4  ["PUT ‘REPO_PATH/s.zip’ HTTP/1.1" 400 0 "-" "p...
#
# [5 rows x 64 columns]

# %%
df['Comments'][700][0]
# Out:
# 'Security General Settings :\n- Allow Anonymous Access\n'

# %%
data = []

# 2. Process each row with similarity above the threshold
for i, (summary, similarity) in enumerate(zip(df['Summary'], sum_similarities)):
    if similarity > 0.5:
        # new_df = new_df.append({
            data.append({
            'Summary': summary,
            'EmbeddingsSummary': embeddings[i],
            'Description': df.loc[i, 'Description'],
            'Comments': df.loc[i, 'Comments']
            })
        # }, ignore_index=True)

new_df = pd.DataFrame.from_records(data)

# %%
new_df.shape
# Out:
# (7, 4)

# %%
new_df.head()
# Out:
#                                              Summary  \
# 0  Invalid authentication removes groups from Cro...
# 1                                      Cannot log-in
# 2  I would to use a certificate as an authenticat...
# 3                            Authentication  problem
# 4                     Random authentification Issues
#
#                                    EmbeddingsSummary  \
# 0  ((tf.Tensor(-0.02690386, shape=(), dtype=float...
# 1  ((tf.Tensor(-0.030607384, shape=(), dtype=floa...
# 2  ((tf.Tensor(-0.02844619, shape=(), dtype=float...
# 3  ((tf.Tensor(-0.014970663, shape=(), dtype=floa...
# 4  ((tf.Tensor(-0.04827584, shape=(), dtype=float...
#
#                                          Description  \
# 0  h3. Steps to reproduce\r\n # Configure Artifac...
# 1  Got internal error when trying to log-in. Trie...
# 2  Instead of just user credentials / api or toke...
# 3  Hi,\nwe had some problems with our artifactory...
# 4  Our Artifactory pro is using the LDAP plugin, ...
#
#                                             Comments
# 0  [Closed this ticket as this is the desired beh...
# 1  [I just fixed it - it is caused by trying to h...
# 2  [No plans to implement at the moment., nan, na...
# 3  [Security General Settings :\n- Allow Anonymou...
# 4  [We are having the exact same problem with LDA...

# %%
new_df['Description'] = new_df['Description'].astype(str)

# %%
embeddings = []

# Iterate through each row of the column
for i in new_df['Description']:
    # Encode the sentence using the USE model
    embedding = use_model([i])
    # Append the embedding to the list
    embeddings.append(embedding)

new_df['embeddingsDescription'] = embeddings

# %%
new_df["embeddingsDescription"] = new_df["embeddingsDescription"].tolist()

# %%
# Function to calculate cosine similarity between sentences
def calculate_similarity(input_sentence, embeddings):
  input_embedding = use_model([input_sentence])

  similarities = []
  for embedding in embeddings:
    similarity = cosine_similarity(input_embedding, embedding)[0][0]
    similarities.append(similarity)

  return similarities

# %%
# Calculate similarity scores
des_similarities = calculate_similarity(des_input_sen, new_df["embeddingsDescription"])

# Display results
for i, row in new_df.iterrows():
  Description = row["Description"]
  similarity = des_similarities[i]
  print(f"Description: {Description}, Similarity: {similarity:.4f}")
# Out:
# Description: h3. Steps to reproduce
#  # Configure Artifactory to use Atlassian Crowd as authentication provider.
#  # Import/sync some (Crowd) groups to Artifactory
#  # Login to Artifactory web UI as a Crowd user with some (Crowd) group permissions that has been imported & configured to Artifactory
#  # Verify that user details shows the groups associated for the user just logged in
#  # Use another browser or browser private window for another session to Artifactory web UI, and make a new login to Artifactory, but now give wrong password
#
# h3. Expected behavior
#
# The second login fails but the first session remains with the same permissions.
# I.e. failed login would not remove any groups & permissions.
# h3. Actual behavior
#
# The failed login triggers removal of all Crowd groups from the user and the permissions are lost.
# Only re-login repopulates the groups & permissions to the user.
# h3. Additional information
#
# If authentication provider is LDAP (AD), failed login won't remove groups. Similar behavior is expected when Crowd is used as authentication provider.
#
# This issue can cause issues in builds, which can be very tricky to resolve.
#
# There is no reason why failed login would trigger group & permission removal. Only successful login with successful data sync should change user's groups & permissions.
#
# As a security aspect, an attacker can use this to block Crowd user to use Artifactory by giving known username and wrong password., Similarity: 0.3687
# Description: Got internal error when trying to log-in. Tried multiple log-out and othere remove pages...
# 2007-03-04 22:37:06,198 [ERROR] protocol.http.WebRequestCycle  - unable to get object, model: Model:classname=[wicket.model.PropertyModel]:attached=true:nestedModel=[[Page class = org.artifactory.webapp.wicket.home.HomePage, id = 1, version = 0]]:expression=[userName]:propertyType=[null], called with component [Component id = username, page = org.artifactory.webapp.wicket.home.HomePage, path = 1:username.Label, isVisible = true, isVersioned = true]
# wicket.WicketRuntimeException: unable to get object, model: Model:classname=[wicket.model.PropertyModel]:attached=true:nestedModel=[[Page class = org.artifactory.webapp.wicket.home.HomePage, id = 1, version = 0]]:expression=[userName]:propertyType=[null], called with component [Component id = username, page = org.artifactory.webapp.wicket.home.HomePage, path = 1:username.Label, isVisible = true, isVersioned = true]
#         at wicket.model.AbstractDetachableModel.getObject(AbstractDetachableModel.java:106)
#         at wicket.Component.getModelObject(Component.java:941)
#         at wicket.Component.getModelObjectAsString(Component.java:956)
#         at wicket.markup.html.basic.Label.onComponentTagBody(Label.java:112)
#         at wicket.Component.renderComponent(Component.java:1646)
#         at wicket.markup.html.WebComponent.onRender(WebComponent.java:60)
#         at wicket.Component.render(Component.java:1484)
#         at wicket.MarkupContainer.renderNext(MarkupContainer.java:1303)
#         at wicket.MarkupContainer.renderComponentTagBody(MarkupContainer.java:951)
#         at wicket.MarkupContainer.onComponentTagBody(MarkupContainer.java:886)
#         at wicket.Component.renderComponent(Component.java:1646)
#         at wicket.MarkupContainer.onRender(MarkupContainer.java:896)
#         at wicket.Component.render(Component.java:1484)
#         at wicket.Component.render(Component.java:1450)
#         at wicket.MarkupContainer.autoAdd(MarkupContainer.java:191)
#         at wicket.markup.resolver.MarkupInheritanceResolver.resolve(MarkupInheritanceResolver.java:65)
#         at wicket.MarkupContainer.renderNext(MarkupContainer.java:1330)
#         at wicket.MarkupContainer.renderComponentTagBody(MarkupContainer.java:951)
#         at wicket.MarkupContainer.onComponentTagBody(MarkupContainer.java:886)
#         at wicket.Component.renderComponent(Component.java:1646)
#         at wicket.MarkupContainer.onRender(MarkupContainer.java:896)
#         at wicket.Component.render(Component.java:1484)
#         at wicket.Component.render(Component.java:1450)
#         at wicket.MarkupContainer.autoAdd(MarkupContainer.java:191)
#         at wicket.markup.resolver.MarkupInheritanceResolver.resolve(MarkupInheritanceResolver.java:72)
#         at wicket.MarkupContainer.renderNext(MarkupContainer.java:1330)
#         at wicket.MarkupContainer.renderComponentTagBody(MarkupContainer.java:951)
#         at wicket.MarkupContainer.onComponentTagBody(MarkupContainer.java:886)
#         at wicket.Component.renderComponent(Component.java:1646)
#         at wicket.MarkupContainer.onRender(MarkupContainer.java:896)
#         at wicket.Component.render(Component.java:1484)
#         at wicket.MarkupContainer.renderNext(MarkupContainer.java:1303)
#         at wicket.MarkupContainer.renderAll(MarkupContainer.java:913)
#         at wicket.Page.onRender(Page.java:1007)
#         at wicket.Component.render(Component.java:1484)
#         at wicket.Page.renderPage(Page.java:411)
#         at wicket.protocol.http.WebRequestCycle.redirectTo(WebRequestCycle.java:158)
#         at wicket.request.target.component.PageRequestTarget.respond(PageRequestTarget.java:59)
#         at wicket.request.AbstractRequestCycleProcessor.respond(AbstractRequestCycleProcessor.java:102)
#         at wicket.RequestCycle.processEventsAndRespond(RequestCycle.java:975)
#         at wicket.RequestCycle.step(RequestCycle.java:1042)
#         at wicket.RequestCycle.steps(RequestCycle.java:1116)
#         at wicket.RequestCycle.request(RequestCycle.java:456)
#         at wicket.protocol.http.WicketFilter.doGet(WicketFilter.java:263)
#         at wicket.protocol.http.WicketFilter.doFilter(WicketFilter.java:133)
#         at org.mortbay.jetty.servlet.ServletHandler$CachedChain.doFilter(ServletHandler.java:1065)
#         at org.artifactory.webapp.servlet.RepoFilter.doFilterInternal(RepoFilter.java:77)
#         at org.artifactory.webapp.servlet.ArtifactoryFilter.doFilter(ArtifactoryFilter.java:61)
#         at org.mortbay.jetty.servlet.ServletHandler$CachedChain.doFilter(ServletHandler.java:1065)
#         at org.artifactory.webapp.servlet.AccessFilter.doFilterInternal(AccessFilter.java:59)
#         at org.artifactory.webapp.servlet.ArtifactoryFilter.doFilter(ArtifactoryFilter.java:61)
#         at org.mortbay.jetty.servlet.ServletHandler$CachedChain.doFilter(ServletHandler.java:1065)
#         at org.mortbay.jetty.servlet.ServletHandler.handle(ServletHandler.java:365)
#         at org.mortbay.jetty.security.SecurityHandler.handle(SecurityHandler.java:185)
#         at org.mortbay.jetty.servlet.SessionHandler.handle(SessionHandler.java:181)
#         at org.mortbay.jetty.handler.ContextHandler.handle(ContextHandler.java:689)
#         at org.mortbay.jetty.webapp.WebAppContext.handle(WebAppContext.java:391)
#         at org.mortbay.jetty.handler.ContextHandlerCollection.handle(ContextHandlerCollection.java:146)
#         at org.mortbay.jetty.handler.HandlerCollection.handle(HandlerCollection.java:114)
#         at org.mortbay.jetty.handler.HandlerWrapper.handle(HandlerWrapper.java:139)
#         at org.mortbay.jetty.Server.handle(Server.java:285)
#         at org.mortbay.jetty.HttpConnection.handleRequest(HttpConnection.java:457)
#         at org.mortbay.jetty.HttpConnection$RequestHandler.content(HttpConnection.java:765)
#         at org.mortbay.jetty.HttpParser.parseNext(HttpParser.java:628)
#         at org.mortbay.jetty.HttpParser.parseAvailable(HttpParser.java:209)
#         at org.mortbay.jetty.HttpConnection.handle(HttpConnection.java:357)
#         at org.mortbay.io.nio.SelectChannelEndPoint.run(SelectChannelEndPoint.java:329)
#         at org.mortbay.thread.BoundedThreadPool$PoolThread.run(BoundedThreadPool.java:475)
# Caused by: wicket.WicketRuntimeException: Error calling method: public java.lang.String org.artifactory.webapp.wicket.ArtifactoryPage.getUserName() on object: [Page class = org.artifactory.webapp.wicket.home.HomePage, id = 1, version = 0]
#         at wicket.util.lang.PropertyResolver$MethodGetAndSet.getValue(PropertyResolver.java:815)
#         at wicket.util.lang.PropertyResolver$ObjectAndGetSetter.getValue(PropertyResolver.java:466)
#         at wicket.util.lang.PropertyResolver.getValue(PropertyResolver.java:91)
#         at wicket.model.AbstractPropertyModel.onGetObject(AbstractPropertyModel.java:131)
#         at wicket.model.AbstractDetachableModel.getObject(AbstractDetachableModel.java:102)
#         ... 67 more
# Caused by: java.lang.NullPointerException
#         at org.artifactory.webapp.wicket.ArtifactoryPage.getUserName(ArtifactoryPage.java:50)
#         at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
#         at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:39)
#         at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:25)
#         at java.lang.reflect.Method.invoke(Method.java:597)
#         at wicket.util.lang.PropertyResolver$MethodGetAndSet.getValue(PropertyResolver.java:811)
#         ... 71 more
# 2007-03-04 22:37:20,150 [ERROR] protocol.http.WebRequestCycle  - unable to get object, model: Model:classname=[wicket.model.PropertyModel]:attached=true:nestedModel=[[Page class = org.artifactory.webapp.wicket.home.HomePage, id = 6, version = 0]]:expression=[userName]:propertyType=[null], called with component [Component id = username, page = org.artifactory.webapp.wicket.home.HomePage, path = 6:username.Label, isVisible = true, isVersioned = true]
# wicket.WicketRuntimeException: unable to get object, model: Model:classname=[wicket.model.PropertyModel]:attached=true:nestedModel=[[Page class = org.artifactory.webapp.wicket.home.HomePage, id = 6, version = 0]]:expression=[userName]:propertyType=[null], called with component [Component id = username, page = org.artifactory.webapp.wicket.home.HomePage, path = 6:username.Label, isVisible = true, isVersioned = true]
#         at wicket.model.AbstractDetachableModel.getObject(AbstractDetachableModel.java:106)
#         at wicket.Component.getModelObject(Component.java:941)
#         at wicket.Component.getModelObjectAsString(Component.java:956)
#         at wicket.markup.html.basic.Label.onComponentTagBody(Label.java:112)
#         at wicket.Component.renderComponent(Component.java:1646)
#         at wicket.markup.html.WebComponent.onRender(WebComponent.java:60)
#         at wicket.Component.render(Component.java:1484)
#         at wicket.MarkupContainer.renderNext(MarkupContainer.java:1303)
#         at wicket.MarkupContainer.renderComponentTagBody(MarkupContainer.java:951)
#         at wicket.MarkupContainer.onComponentTagBody(MarkupContainer.java:886)
#         at wicket.Component.renderComponent(Component.java:1646)
#         at wicket.MarkupContainer.onRender(MarkupContainer.java:896)
#         at wicket.Component.render(Component.java:1484)
#         at wicket.Component.render(Component.java:1450)
#         at wicket.MarkupContainer.autoAdd(MarkupContainer.java:191)
#         at wicket.markup.resolver.MarkupInheritanceResolver.resolve(MarkupInheritanceResolver.java:65)
#         at wicket.MarkupContainer.renderNext(MarkupContainer.java:1330)
#         at wicket.MarkupContainer.renderComponentTagBody(MarkupContainer.java:951)
#         at wicket.MarkupContainer.onComponentTagBody(MarkupContainer.java:886)
#         at wicket.Component.renderComponent(Component.java:1646)
#         at wicket.MarkupContainer.onRender(MarkupContainer.java:896)
#         at wicket.Component.render(Component.java:1484)
#         at wicket.Component.render(Component.java:1450)
#         at wicket.MarkupContainer.autoAdd(MarkupContainer.java:191)
#         at wicket.markup.resolver.MarkupInheritanceResolver.resolve(MarkupInheritanceResolver.java:72)
#         at wicket.MarkupContainer.renderNext(MarkupContainer.java:1330)
#         at wicket.MarkupContainer.renderComponentTagBody(MarkupContainer.java:951)
#         at wicket.MarkupContainer.onComponentTagBody(MarkupContainer.java:886)
#         at wicket.Component.renderComponent(Component.java:1646)
#         at wicket.MarkupContainer.onRender(MarkupContainer.java:896)
#         at wicket.Component.render(Component.java:1484)
#         at wicket.MarkupContainer.renderNext(MarkupContainer.java:1303)
#         at wicket.MarkupContainer.renderAll(MarkupContainer.java:913)
#         at wicket.Page.onRender(Page.java:1007)
#         at wicket.Component.render(Component.java:1484)
#         at wicket.Page.renderPage(Page.java:411)
#         at wicket.protocol.http.WebRequestCycle.redirectTo(WebRequestCycle.java:158)
#         at wicket.request.target.component.PageRequestTarget.respond(PageRequestTarget.java:59)
#         at wicket.request.AbstractRequestCycleProcessor.respond(AbstractRequestCycleProcessor.java:102)
#         at wicket.RequestCycle.processEventsAndRespond(RequestCycle.java:975)
#         at wicket.RequestCycle.step(RequestCycle.java:1042)
#         at wicket.RequestCycle.steps(RequestCycle.java:1116)
#         at wicket.RequestCycle.request(RequestCycle.java:456)
#         at wicket.protocol.http.WicketFilter.doGet(WicketFilter.java:263)
#         at wicket.protocol.http.WicketFilter.doFilter(WicketFilter.java:133)
#         at org.mortbay.jetty.servlet.ServletHandler$CachedChain.doFilter(ServletHandler.java:1065)
#         at org.artifactory.webapp.servlet.RepoFilter.doFilterInternal(RepoFilter.java:77)
#         at org.artifactory.webapp.servlet.ArtifactoryFilter.doFilter(ArtifactoryFilter.java:61)
#         at org.mortbay.jetty.servlet.ServletHandler$CachedChain.doFilter(ServletHandler.java:1065)
#         at org.artifactory.webapp.servlet.AccessFilter.doFilterInternal(AccessFilter.java:59)
#         at org.artifactory.webapp.servlet.ArtifactoryFilter.doFilter(ArtifactoryFilter.java:61)
#         at org.mortbay.jetty.servlet.ServletHandler$CachedChain.doFilter(ServletHandler.java:1065)
#         at org.mortbay.jetty.servlet.ServletHandler.handle(ServletHandler.java:365)
#         at org.mortbay.jetty.security.SecurityHandler.handle(SecurityHandler.java:185)
#         at org.mortbay.jetty.servlet.SessionHandler.handle(SessionHandler.java:181)
#         at org.mortbay.jetty.handler.ContextHandler.handle(ContextHandler.java:689)
#         at org.mortbay.jetty.webapp.WebAppContext.handle(WebAppContext.java:391)
#         at org.mortbay.jetty.handler.ContextHandlerCollection.handle(ContextHandlerCollection.java:146)
#         at org.mortbay.jetty.handler.HandlerCollection.handle(HandlerCollection.java:114)
#         at org.mortbay.jetty.handler.HandlerWrapper.handle(HandlerWrapper.java:139)
#         at org.mortbay.jetty.Server.handle(Server.java:285)
#         at org.mortbay.jetty.HttpConnection.handleRequest(HttpConnection.java:457)
#         at org.mortbay.jetty.HttpConnection$RequestHandler.content(HttpConnection.java:765)
#         at org.mortbay.jetty.HttpParser.parseNext(HttpParser.java:628)
#         at org.mortbay.jetty.HttpParser.parseAvailable(HttpParser.java:209)
#         at org.mortbay.jetty.HttpConnection.handle(HttpConnection.java:357)
#         at org.mortbay.io.nio.SelectChannelEndPoint.run(SelectChannelEndPoint.java:329)
#         at org.mortbay.thread.BoundedThreadPool$PoolThread.run(BoundedThreadPool.java:475)
# Caused by: wicket.WicketRuntimeException: Error calling method: public java.lang.String org.artifactory.webapp.wicket.ArtifactoryPage.getUserName() on object: [Page class = org.artifactory.webapp.wicket.home.HomePage, id = 6, version = 0]
#         at wicket.util.lang.PropertyResolver$MethodGetAndSet.getValue(PropertyResolver.java:815)
#         at wicket.util.lang.PropertyResolver$ObjectAndGetSetter.getValue(PropertyResolver.java:466)
#         at wicket.util.lang.PropertyResolver.getValue(PropertyResolver.java:91)
#         at wicket.model.AbstractPropertyModel.onGetObject(AbstractPropertyModel.java:131)
#         at wicket.model.AbstractDetachableModel.getObject(AbstractDetachableModel.java:102)
#         ... 67 more
# Caused by: java.lang.NullPointerException
#         at org.artifactory.webapp.wicket.ArtifactoryPage.getUserName(ArtifactoryPage.java:50)
#         at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
#         at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:39)
#         at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:25)
#         at java.lang.reflect.Method.invoke(Method.java:597)
#         at wicket.util.lang.PropertyResolver$MethodGetAndSet.getValue(PropertyResolver.java:811)
#         ... 71 more
# , Similarity: 0.2456
# Description: Instead of just user credentials / api or token as authentication option.
#
# It would be useful for security to be able to use a certificate file to authenticate an user or specially an application account like Jenkins.
#
# In fact, the use of a certificate could prevent the operator using Jenkins from knowing or printing the credentials / api or token.
#
# In case of certificate file, the operator could only find out the path of the certificate.
#
#
#
# thank you for considering this request, Similarity: 0.2691
# Description: Hi,
# we had some problems with our artifactory when the user access a virtual repo which has an local repo who you need an authenticated user.
#
#
# * virtual repo
# **  local repo 1
# **  local repo 2
# **  external repo 1
# ** external repo 2
#
#
# Permissions Management:
#  - Any Remote (on any remote repo): anonymous -> deploy
#  - local-repo1-permission (local repo 1): reader-user -> read, deployer-user -> delete, deploy, annotate, read
#  - local-repo2-permission (local repo 2): reader-user -> read, deployer-user -> read
#
# The problem occur when the needed jar is in "local repo 1" and your credential are from one of the both users, Similarity: 1.0000
# Description: Our Artifactory pro is using the LDAP plugin, to a OpenDJ LDAP which is used by many tools without issues, except now Artifactory
#
# I don't know if this is related to RTFACT-7173, but we having serious issues since 3.6.0. I'm thinking, without be sure, it was ok on 3.5.x:
# - Many jenkins build fail randomly because not authorised/authenticated on Artifactory. This builds are ok, passing well before artifactory updates and are still ok when Artifactory allow it...
# - From an user/web point of view, also randomly, Artifactory is blocking authentification of many/everybody, with a wrong password message. Sometime this is going back to normal alone, and sometime we have to restart Artifactory.
#
# , Similarity: 0.3659
# Description: This is for MYRIAD-22 .
# I'm pleased if I could have some feedbacks., Similarity: -0.0741
# Description: inspiration: http://www.tornadoweb.org/documentation#user-authentication, Similarity: -0.0480

# %%
len(des_similarities)
# Out:
# 7

# %%
# Store descriptions with similarity > 0.7 and their scores in a list
similar_descriptions_and_scores = []
for Description, similarity in zip(new_df["Description"], des_similarities):
  if similarity > 0.5:
    similar_descriptions_and_scores.append((Description, similarity))

# Sort similar descriptions by similarity score (highest first)
sorted_similar_descriptions_and_scores = sorted(similar_descriptions_and_scores, key=lambda x: x[1], reverse=True)

# Print top 5 similar sentences and their scores
for i, (Description, similarity) in enumerate(sorted_similar_descriptions_and_scores):
  if i == 5:
    break  # Print only the top 5
  print(f"Similar Description: {Description} \n , Similarity: {similarity:.4f} \n")
# Out:
# Similar Description: Hi,
# we had some problems with our artifactory when the user access a virtual repo which has an local repo who you need an authenticated user.
#
#
# * virtual repo
# **  local repo 1
# **  local repo 2
# **  external repo 1
# ** external repo 2
#
#
# Permissions Management:
#  - Any Remote (on any remote repo): anonymous -> deploy
#  - local-repo1-permission (local repo 1): reader-user -> read, deployer-user -> delete, deploy, annotate, read
#  - local-repo2-permission (local repo 2): reader-user -> read, deployer-user -> read
#
# The problem occur when the needed jar is in "local repo 1" and your credential are from one of the both users
#  , Similarity: 1.0000

# %%
len(similar_descriptions_and_scores)
# Out:
# 1

# %%
similar_descriptions_and_scores[0]
# Out:
# ('Hi,\nwe had some problems with our artifactory when the user access a virtual repo which has an local repo who you need an authenticated user.\n\n\n* virtual repo\n**  local repo 1\n**  local repo 2\n**  external repo 1\n** external repo 2\n\t\n\nPermissions Management:\n - Any Remote (on any remote repo): anonymous -> deploy\n - local-repo1-permission (local repo 1): reader-user -> read, deployer-user -> delete, deploy, annotate, read\n - local-repo2-permission (local repo 2): reader-user -> read, deployer-user -> read\n\nThe problem occur when the needed jar is in "local repo 1" and your credential are from one of the both users',
#  1.0000001)

# %% [markdown]
# ### Comments

# %%
model = hub.load('https://tfhub.dev/google/universal-sentence-encoder-multilingual/3')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in op_def_for_type(self, type)
#    3016     try:
# -> 3017       return self._op_def_cache[type]
#    3018     except KeyError:
#
# KeyError: 'SentencepieceOp'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-45-0abbf47b3b21> in <cell line: 1>()
# ----> 1 model = hub.load('https://tfhub.dev/google/universal-sentence-encoder-multilingual/3')
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_hub/module_v2.py in load(handle, tags, options)
#     124         module_path, tags=tags, options=options)
#     125   else:
# --> 126     obj = tf.compat.v1.saved_model.load_v2(module_path, tags=tags)
#     127   obj._is_hub_module_v1 = is_hub_module_v1  # pylint: disable=protected-access
#     128   return obj
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/saved_model/load.py in load(export_dir, tags, options)
#     910   if isinstance(export_dir, os.PathLike):
#     911     export_dir = os.fspath(export_dir)
# --> 912   result = load_partial(export_dir, None, tags, options)["root"]
#     913   return result
#     914
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/saved_model/load.py in load_partial(export_dir, filters, tags, options)
#    1041     with ops.init_scope():
#    1042       try:
# -> 1043         loader = Loader(object_graph_proto, saved_model_proto, export_dir,
#    1044                         ckpt_options, options, filters)
#    1045       except errors.NotFoundError as err:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/saved_model/load.py in __init__(self, object_graph_proto, saved_model_proto, export_dir, ckpt_options, save_options, filters)
#     159     self._export_dir = export_dir
#     160     self._concrete_functions = (
# --> 161         function_deserialization.load_function_def_library(
#     162             library=meta_graph.graph_def.library,
#     163             saved_object_graph=self._proto,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/saved_model/function_deserialization.py in load_function_def_library(library, saved_object_graph, load_shared_name_suffix, wrapper_function)
#     454     # import).
#     455     with graph.as_default():
# --> 456       func_graph = function_def_lib.function_def_to_graph(
#     457           fdef,
#     458           structured_input_signature=structured_input_signature,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/function_def_to_graph.py in function_def_to_graph(fdef, structured_input_signature, structured_outputs, input_shapes, propagate_device_spec, include_library_functions)
#      89           input_shapes.append(input_shape)
#      90
# ---> 91   graph_def, nested_to_flat_tensor_name = function_def_to_graph_def(
#      92       fdef, input_shapes, include_library_functions=include_library_functions
#      93   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/function_def_to_graph.py in function_def_to_graph_def(fdef, input_shapes, include_library_functions)
#     328           graph_def.library.gradient.extend([grad_def])
#     329     else:
# --> 330       op_def = default_graph.op_def_for_type(node_def.op)  # pylint: disable=protected-access
#     331
#     332     for attr in op_def.attr:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in op_def_for_type(self, type)
#    3018     except KeyError:
#    3019       self._op_def_cache[type] = op_def_pb2.OpDef.FromString(
# -> 3020           self._op_def_for_type(type)
#    3021       )
#    3022       return self._op_def_cache[type]
#
# RuntimeError: Op type not registered 'SentencepieceOp' in binary running on 82ba1cc1b91b. Make sure the Op and Kernel are registered in the binary running in this process. Note that if you are loading a saved graph which used ops from tf.contrib (e.g. `tf.contrib.resampler`), accessing should be done before importing the graph, as contrib ops are lazily registered when the module is first accessed.

# %%
comments_for_similar_descriptions = []

for description, similarity in similar_descriptions_and_scores:

  # Find the index of the matching description in the original DataFrame
  description_index = new_df[new_df['Description'] == description].index[0]

  # Extract the corresponding comment
  comment = new_df.loc[description_index, 'Comments']

  # Append a tuple (description, similarity, comment) to the comments list
  comments_for_similar_descriptions.append((comment))

# %%
emb_coms = []
for comment in comments_for_similar_descriptions :
  emb_com = use_model(comment)
  emb_coms.append(emb_com)

# %%
query_embedding = model([des_input_sen])
cosines = []
# for i in emb_coms:
#   ss_score = util.semantic_search(query_embedding, i)
#   s_search.append(ss_score)

def semantic_search(query_embedding, corpus, document_ids=None):

  # Calculate cosine similarities between query and corpus embeddings
  for emb_com in emb_coms:
      cosine = cosine_similarity(query_embedding, emb_com)
      cosines.append(cosine)
  top_k_indices = tf.math.top_k(cosines, k=k).indices.numpy()  # Most similar indices
  top_k_similar_docs = [corpus[i] for i in top_k_indices.flatten()]
  top_k_distances = cosines.numpy().flatten()[top_k_indices.flatten()]  # Distances

  if document_ids is not None:
    top_k_document_ids = [document_ids[i] for i in top_k_indices.flatten()]
    return top_k_similar_docs, top_k_distances, top_k_document_ids
  else:
    return top_k_similar_docs, top_k_distances

# Example usage
k = 5  # Number of top similar documents to retrieve

top_similar_docs, top_distances = semantic_search(query_embedding, comments_for_similar_descriptions)
print("Top", k, "similar documents:")
for i, doc in enumerate(top_similar_docs):
  print(f"{i+1}. {doc} (distance: {top_distances[i]:.4f})")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-2f465e863cfc> in <cell line: 26>()
#      24 k = 5  # Number of top similar documents to retrieve
#      25
# ---> 26 top_similar_docs, top_distances = semantic_search(query_embedding, comments_for_similar_descriptions)
#      27 print("Top", k, "similar documents:")
#      28 for i, doc in enumerate(top_similar_docs):
#
# <ipython-input-55-2f465e863cfc> in semantic_search(query_embedding, corpus, document_ids)
#      12       cosines.append(cosine)
#      13   top_k_indices = tf.math.top_k(cosines, k=k).indices.numpy()  # Most similar indices
# ---> 14   top_k_similar_docs = [corpus[i] for i in top_k_indices.flatten()]
#      15   top_k_distances = cosines.numpy().flatten()[top_k_indices.flatten()]  # Distances
#      16
#
# <ipython-input-55-2f465e863cfc> in <listcomp>(.0)
#      12       cosines.append(cosine)
#      13   top_k_indices = tf.math.top_k(cosines, k=k).indices.numpy()  # Most similar indices
# ---> 14   top_k_similar_docs = [corpus[i] for i in top_k_indices.flatten()]
#      15   top_k_distances = cosines.numpy().flatten()[top_k_indices.flatten()]  # Distances
#      16
#
# IndexError: list index out of range
